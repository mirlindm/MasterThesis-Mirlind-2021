# %% [markdown]
# ## **Upload the dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-78c03029-e405-4fd7-96fe-f075a70aaec8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78c03029-e405-4fd7-96fe-f075a70aaec8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving timob_dataframe.csv to timob_dataframe.csv

# %% [markdown]
# ## **Reading the dataset. Providing initial descriptives for the project's data. Before cleaning stage.**

# %%
import pandas as pd

timob_df = pd.read_csv("timob_dataframe.csv") 

print("\n******************************\n")
print("Printing Dataset Initial Shape: \n")
print(timob_df.shape)
print("\n******************************\n")
print("Printing Dataset Initial Descriptives: \n")
print(timob_df.describe())
print("\n******************************\n")
print("Printing Dataset Information: \n")
print(timob_df.info())

# %%
print("\n Check the number of total missing values in the Open-Source Project \n")
#To-DO
print(timob_df.isnull())
print("\n Check the data fields that contain missing values in the Open-Source Project \n")
#To-DO
print(timob_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(timob_df.isnull().sum().sum())

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses Before Cleaning the Data**

# %%
print("Number of sprints: \n")
print(timob_df.sprint.nunique())
print(timob_df.sprint.unique())
print('\n\n')
print(len(timob_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 107
# [nan 'Documentation Sprint 03 - 2016' '2014 Sprint 01'
#  '2014 Sprint 01 API' '2014 Sprint 07' '2014 Sprint 07 Tooling'
#  '2013 Sprint 24' '2013 Sprint 24 Core' '2013 Sprint 23'
#  '2013 Sprint 23 Core' '2013 Sprint 23 Tooling' '2013 Sprint 23 API'
#  '2014 Sprint 06' '2014 Sprint 06 SDK' '2014 Sprint 05'
#  '2014 Sprint 05 API' '2013 Sprint 20' '2013 Sprint 20 Tooling'
#  '2013 Sprint 18' '2013 Sprint 18 Tooling' '2013 Sprint 21'
#  '2013 Sprint 21 Core' '2013 Sprint 20 Core' '2013 Sprint 19'
#  '2013 Sprint 19 Core' '2013 Sprint 18 Core' '2013 Sprint 25'
#  '2013 Sprint 25 Tooling' '2013 Sprint 16' '2013 Sprint 16 Core'
#  '2013 Sprint 18 API' '2013 Sprint 15 Tooling' '2013 Sprint 15'
#  '2013 Sprint 14' '2013 Sprint 14 Tooling' '2013 Sprint 15 API'
#  '2013 Sprint 08 API' '2013 Sprint 08' '2013 Sprint 22'
#  '2013 Sprint 22 Core' '2013 Sprint 07 BB' '2013 Sprint 07'
#  '2013 Sprint 04 JS' '2013 Sprint 04' '2013 Sprint 06 BB' '2013 Sprint 06'
# ...

# %%
print("Number of issues: \n")
print(timob_df.key.nunique())
print(timob_df.key.unique())
print('\n\n')
print(len(timob_df.key.unique()))
# Out:
# Number of issues:
#
# 1990
# ['TIMOB-23248' 'TIMOB-23247' 'TIMOB-23246' ... 'TIMOB-1097' 'TIMOB-684'
#  'TIMOB-559']
#
#
#
# 1990

# %%
print("Number of developers: \n")
print(timob_df['assignee.name'].nunique())
print('\n\n')
print(timob_df['assignee.name'].unique())
print('\n\n')
print(len(timob_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 49
#
#
#
# ['kota' 'cwilliams' 'msamah' 'apetkov' 'gmathews' 'hansknoechel' 'fokkezb'
#  'cng' 'fmiao' 'penrique' 'ssombhatla' 'hpham' 'cbarber' 'jhaynie'
#  'pinnamuri' 'dtoth' 'eharris' 'bhatfield' 'ingo' 'mdadu' 'vduggal'
#  'jalter' 'rmcmahon' 'skypanther' 'mlangston' 'sunila' 'pwang' 'mpmiranda'
#  'srahim' 'ayeung' 'csullivan' 'bhughes' 'joshroesslein' 'mstepanov'
#  'sdowse' 'billdawson' 'jlemieux' 'hmovsisyan' 'dlifshitz' 'dcampbell'
#  'agalstyan' 'jithinv@exalture.com' 'opiecyrus' 'stephentramer'
#  'mculpepper' 'ngupta' 'fboisvert' 'blainhamon' 'chaseculpepper22']
#
#
#
# 49

# %%
print("Number of reporters: \n")
print(timob_df['reporter.name'].nunique())
print('\n\n')
print(timob_df['reporter.name'].unique())
print('\n\n')
print(len(timob_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 335
#
#
#
# ['kota' 'buder' 'rramirez' 'eharris' 'htbryant' 'nkapupara@tacme.com'
#  'jonasbjurhult' 'topener' 'hansknoechel' 'bgarcia' 'apetkov' 'kellycorn'
#  'rmitro' 'ngweixing' 'cwilliams' 'fokkezb' 'wluu' 'michael' 'ibinaydas'
#  'Suraj Datta' 'cng' 'penrique' 'pragmateq' 'falko' 'zozo4kin' 'sliang'
#  'teunklijn@telfort.nl' 'CREATIVE KAIZEN' 'paramsb' 'john.surface'
#  'ssombhatla' 'aislam' 'elberto' 'joef' 'ben.bahrenburg@gmail.com'
#  'lchoudhary' 'threethirds' 'fmiao' 'morahman' 'ewieber'
#  'echeung@leviton.com' 'mano_mykingdom' 'parnanzio' 'kosso' 'iwhitfield'
#  'g4be' 'eric.harms@gmail.com' 'nitrag' 'msamah' 'janvankampen' 'jlongton'
#  'developer82' 'astrovicapps' 'martijnkooij' 'bgrantges@appcelerator.com'
#  'luca.dellaira' 'thomas.neerup@eg.dk' 'cbarber' 'lbrenman' 'gmathews'
#  'max87' 'shawnlan' 'giokve' 'annakozy@direcciona.me' 'AlbWebbergate'
#  'egomez' 'rpeshwe' 'kenjorai' 'rblalock' 'prafull3313'
# ...

# %%
print("Number of issue status: \n")
print(timob_df['status.name'].nunique())
print('\n\n')
print(timob_df['status.name'].unique())
print('\n\n')
print(len(timob_df['status.name'].unique()))

# %% [markdown]
# ## **Exploring the dataset's columns and their missing values! *Before cleaning stage.**

# %%
print(f'There are {len(timob_df.columns)} columns in the dataset.')
print("\n******************************\n")
print("Printing Dataset Columns Below: \n")
print(timob_df.columns)

# %%
print('Printing some data from the dataset for ilustration purpose: \n')
timob_df.head()

# %%
# Checking for missing values within the data fields before cleaning the data!

print(f"\nThere are: {timob_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {timob_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {timob_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {timob_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {timob_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {timob_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {timob_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {timob_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {timob_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {timob_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# # **Cleaning the dataset**

# %% [markdown]
# ## **1. Removing unnecessary and useless data fields!**

# %%
# Data cleaning steps

# Remove the unwanted columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount.

timob_df.drop(columns=['components', 'fixVersions', 'issuetype.subtask', 'versions', 'watches.watchCount', 'resolution.description', 'resolution.name'], inplace = True)

print("\n Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset! \n")

print(f'\n There are now {len(timob_df.columns)} columns in the dataset.\n')
print(f"\n Printing Data Fields Below: \n {timob_df.columns} \n")
# Out:
#  Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset!
#
#
#  There are now 17 columns in the dataset.
#
#
#  Printing Data Fields Below:
#  Index(['assignee.name', 'created', 'creator.name', 'description',
#        'issuetype.name', 'priority.name', 'reporter.name', 'resolutiondate',
#        'status.id', 'status.name', 'status.statusCategory.name', 'summary',
#        'updated', 'key', 'storypoints', 'project', 'sprint'],
#       dtype='object')

# %%
print("Printing the new dataset: \n")

timob_df.head()

# %% [markdown]
# ##**2. Removing the duplicate issues, only keeping one instance of them! Removing isses that have same issue_identifier (KEY)!**

# %%
#Data cleaning steps

# 1.  Remove duplicated issue reports: it doesn't make sense to have ISSUE REPORTS that 
#     have exactly the same content since it was probably a mistake from data input.

# Select all duplicate rows based on column: key
duplicateRowsDF = timob_df[timob_df.duplicated(['key'])]
print(f"\nThere are: {len(duplicateRowsDF)} issue duplicates! \n")


print(f"{timob_df['key'].value_counts().head(150)} \n\n")
print(f"Count of column: key, before cleaning is: {timob_df['key'].count()}\n\n")
print(f"Printing some example issues that have the same identifier: \n")
# print(timob_df.loc[timob_df['key'] == 'XD-1507'])
# print(timob_df.loc[timob_df['key'] == 'XD-371'])
# print(timob_df.loc[timob_df['key'] == 'XD-375'])
# Out:
# There are: 154 issue duplicates!
#
# TIMOB-13520    4
# TIMOB-12960    4
# TIMOB-3180     4
# TIMOB-15718    4
# TIMOB-14806    3
#               ..
# TIMOB-19004    1
# TIMOB-19386    1
# TIMOB-8826     1
# TIMOB-19566    1
# TIMOB-20601    1
# Name: key, Length: 150, dtype: int64
#
#
# Count of column: key, before cleaning is: 2144
#
#
# Printing some example issues that have the same identifier:

# %%
# Continuation from previous cell

# Select all duplicate rows based on one column
#duplicateRowsDF = timob_df[timob_df.duplicated(['key'])]
#print(f"\n There are: {len(duplicateRowsDF)} issue duplicates! \n")

#print('\n*************************************************\n')

# Here I am dropping all duplicates, while only keeping the first instance!
timob_df = timob_df.drop_duplicates(subset='key', keep='first')

print(f"Count of column: key, after cleaning is: {timob_df['key'].count()}\n\n")
print(f"{timob_df['key'].value_counts()}\n\n")
print(timob_df.loc[timob_df['key'] == 'XD-1507'])
print(timob_df.loc[timob_df['key'] == 'XD-371'])
print(timob_df.loc[timob_df['key'] == 'XD-375'])


# Here I check for duplicate rows based on all columns, 
# i.e. rows where all columns have same values. 
duplicated = timob_df[timob_df.duplicated()]
print(f"\nFinally, there are: {len(duplicated)} duplicates")
# Out:
# Count of column: key, after cleaning is: 1990
#
#
# TIMOB-18789    1
# TIMOB-17806    1
# TIMOB-16450    1
# TIMOB-19679    1
# TIMOB-17584    1
#               ..
# TIMOB-20302    1
# TIMOB-14980    1
# TIMOB-15716    1
# TIMOB-17411    1
# TIMOB-19692    1
# Name: key, Length: 1990, dtype: int64
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **3. Removing issues that do not have a creator.name recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty creator field. by default, 
#     all issues have to have a creator in JIRA

print(f"Count of column: creator.name, before cleaning is: {timob_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name before cleaning, is: {timob_df['creator.name'].isnull().sum()}. \n\n\n\n")

timob_df.dropna(subset = ["creator.name"], inplace=True)

print(f"Count of column: creator.name, after cleaning is: {timob_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name after cleaning, is: {timob_df['creator.name'].isnull().sum()}. \n\n")

print(timob_df['creator.name'].value_counts())

print('\n\n')
print(timob_df.loc[(timob_df['creator.name'] == '')])
print('\n\n')
timob_df.loc[(timob_df['creator.name'].isnull())]
# Out:
# Count of column: creator.name, before cleaning is: 1989
#
# Count of missing values in the field: creator.name before cleaning, is: 0.
#
#
#
#
# Count of column: creator.name, after cleaning is: 1989
#
# Count of missing values in the field: creator.name after cleaning, is: 0.
#
#
# Count of column: creator.name, after cleaning is: 1989
#
# cwilliams       193
# kota            124
# fokkezb         118
# ingo            107
# eharris          72
#                ...
# dlewis23          1
# underlabs         1
# robgabbard        1
# cesa              1
# rahuljaiswal      1
# Name: creator.name, Length: 345, dtype: int64
#
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **4. Removing empty issues, i.e. issues that do not have a description and summary.**

# %%
#Data cleaning steps

# 3.  issue reports with empty title or body: 
#     these are probably data input errors or tests, meaningless reports. 

print(f"Count of column: key, before removing issues with no description is: {timob_df['key'].count()}\n\n")
print(f"\n There are: {timob_df['description'].isnull().sum()}  missing values in the DESCRIPTION field! \n")
print(f"\n There are: {timob_df['summary'].isnull().sum()}  missing values in the SUMMARY field! \n")

#timob_df[(timob_df['issuetype.name'].isnull())&timob_df['description'].isnull()&timob_df['summary'].isnull()]
#timob_df[(timob_df['issuetype.name'].isnull())|timob_df['description'].isnull()|timob_df['summary'].isnull()].head(150)
# Out:
# Count of column: key, before removing issues with no description is: 1989
#
#
#
#  There are: 136  missing values in the DESCRIPTION field!
#
#
#  There are: 0  missing values in the SUMMARY field!

# %%
timob_df.dropna(subset=['description'], inplace=True)
print(f"Count of column: key, after removing issues with no description is: {timob_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description is: 1853

# %%
timob_df.dropna(subset=['description', 'summary'], inplace=True)
print(f"Count of column: key, after removing issues with no description (summary too) is: {timob_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description (summary too) is: 1853

# %% [markdown]
# ## **5. Removing issues that do not have a ASSIGNEE.NAME recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty asignee.name field.

print(f"Count of column: assignee.name, before cleaning is: {timob_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name before cleaning, is: {timob_df['assignee.name'].isnull().sum()}. \n\n\n\n")

#timob_df.dropna(subset = ["assignee.name"], inplace=True)

print(f"Count of column: assignee.name, after cleaning is: {timob_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name after cleaning, is: {timob_df['assignee.name'].isnull().sum()}. \n\n")

print(timob_df['assignee.name'].value_counts())
print('\n\n')
print(timob_df['assignee.name'].unique())
print('\n\n')
print(timob_df.loc[(timob_df['assignee.name'] == '')])
print('\n\n')
timob_df.loc[(timob_df['assignee.name'].isnull())]

# %% [markdown]
# # **After Cleaning the Data**

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses After Cleaning the Data**

# %%
print("Number of sprints: \n")
print(timob_df.sprint.nunique())
print(timob_df.sprint.unique())
print('\n\n')
print(len(timob_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 63
# [nan 'Documentation Sprint 03 - 2016' '2014 Sprint 01' '2014 Sprint 07'
#  '2013 Sprint 24' '2013 Sprint 23' '2014 Sprint 06' '2014 Sprint 05'
#  '2013 Sprint 20' '2013 Sprint 18' '2013 Sprint 21' '2013 Sprint 19'
#  '2013 Sprint 18 Core' '2013 Sprint 16' '2013 Sprint 15 Tooling'
#  '2013 Sprint 14' '2013 Sprint 15 API' '2013 Sprint 08 API'
#  '2013 Sprint 07 BB' '2013 Sprint 04 JS' '2013 Sprint 06 BB'
#  '2013 Sprint 02 JS' '2013 Sprint 04 API' '2013 Sprint 05 BB'
#  '2013 Sprint 09 BB' '2013 Sprint 02 BB' '2012 Sprint 26' '2012 Sprint 24'
#  '2013 Sprint 13 BB' '2013 Sprint 03 Core' '2012 Sprint 20'
#  '2013 Sprint 04 BB' '2013 Sprint 03 BB' '2013 Sprint 22'
#  'Sprint 2012-13 BB' 'Sprint 2012-20 Core' 'Sprint 2012-11 BB'
#  'Sprint 2012-12 BB' 'Sprint 2012-10 BB' 'Sprint 2012-09 BB'
#  'Sprint 2012-12 API' 'Sprint 2012-08 BB' 'Sprint 2012-07 BB'
#  'Sprint 2012-06 BB' 'Sprint 2012-05 BB' 'Sprint 2012-12 Core'
# ...

# %%
print("Number of issues: \n")
print(timob_df.key.nunique())
print(timob_df.key.unique())
print('\n\n')
print(len(timob_df.key.unique()))
# Out:
# Number of issues:
#
# 1853
# ['TIMOB-23248' 'TIMOB-23247' 'TIMOB-23246' ... 'TIMOB-1242' 'TIMOB-684'
#  'TIMOB-559']
#
#
#
# 1853

# %%
print("Number of developers: \n")
print(timob_df['assignee.name'].nunique())
print('\n\n')
print(timob_df['assignee.name'].unique())
print('\n\n')
print(len(timob_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 49
#
#
#
# ['kota' 'cwilliams' 'msamah' 'apetkov' 'gmathews' 'hansknoechel' 'fokkezb'
#  'cng' 'fmiao' 'penrique' 'ssombhatla' 'hpham' 'cbarber' 'jhaynie'
#  'pinnamuri' 'dtoth' 'eharris' 'bhatfield' 'ingo' 'mdadu' 'vduggal'
#  'jalter' 'rmcmahon' 'skypanther' 'mlangston' 'sunila' 'pwang' 'mpmiranda'
#  'srahim' 'ayeung' 'csullivan' 'bhughes' 'joshroesslein' 'sdowse'
#  'billdawson' 'hmovsisyan' 'agalstyan' 'dcampbell' 'jlemieux' 'dlifshitz'
#  'jithinv@exalture.com' 'opiecyrus' 'stephentramer' 'mculpepper' 'ngupta'
#  'fboisvert' 'blainhamon' 'mstepanov' 'chaseculpepper22']
#
#
#
# 49

# %%
print("Number of reporters: \n")
print(timob_df['reporter.name'].nunique())
print('\n\n')
print(timob_df['reporter.name'].unique())
print('\n\n')
print(len(timob_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 335
#
#
#
# ['kota' 'buder' 'rramirez' 'eharris' 'htbryant' 'nkapupara@tacme.com'
#  'jonasbjurhult' 'topener' 'hansknoechel' 'bgarcia' 'apetkov' 'kellycorn'
#  'rmitro' 'ngweixing' 'cwilliams' 'fokkezb' 'wluu' 'michael' 'ibinaydas'
#  'Suraj Datta' 'cng' 'penrique' 'pragmateq' 'falko' 'zozo4kin' 'sliang'
#  'teunklijn@telfort.nl' 'CREATIVE KAIZEN' 'paramsb' 'john.surface'
#  'ssombhatla' 'aislam' 'elberto' 'joef' 'ben.bahrenburg@gmail.com'
#  'lchoudhary' 'threethirds' 'fmiao' 'morahman' 'ewieber'
#  'echeung@leviton.com' 'mano_mykingdom' 'parnanzio' 'kosso' 'iwhitfield'
#  'g4be' 'eric.harms@gmail.com' 'nitrag' 'msamah' 'janvankampen' 'jlongton'
#  'developer82' 'astrovicapps' 'martijnkooij' 'bgrantges@appcelerator.com'
#  'luca.dellaira' 'thomas.neerup@eg.dk' 'cbarber' 'lbrenman' 'gmathews'
#  'max87' 'shawnlan' 'giokve' 'annakozy@direcciona.me' 'AlbWebbergate'
#  'egomez' 'rpeshwe' 'kenjorai' 'rblalock' 'prafull3313'
# ...

# %% [markdown]
# ## **Exploring the dataset after cleaning (General Descriptives, etc.)**

# %%
print("\n******************************\n")
print("Printing Dataset Shape After Cleaning: \n")
print(timob_df.shape)
print("\n******************************\n")
print("Printing Dataset Descriptives After Cleaning: \n")
print(timob_df.describe())
print("\n******************************\n")
print("Printing Dataset Information After Cleaning: \n")
print(timob_df.info())

# %% [markdown]
# ## **Analyzing the cleaned data below (Missing Values)**

# %%
print("\nCheck the number of total missing values in the Open-Source Project \n")
print(timob_df.isnull())
print("\n\n******************************\n")
print("\nCheck the data fields that contain missing values in the Open-Source Project \n")
print(timob_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(timob_df.isnull().sum().sum())

# %%
# Checking for missing values after cleaning the data!

print(f"\nThere are: {timob_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {timob_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {timob_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {timob_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {timob_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {timob_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {timob_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {timob_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {timob_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {timob_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# ## **Checking for Scrum Rules. After cleaning stage**

# %%
print("\n Check the unique developers (usernames) in the Open-Source Project \n")
#Count and report the unique values

print(len(timob_df['assignee.name'].unique()))
print('\n****************************************************\n')
timob_df['assignee.name'].unique()

# %%
print("\n Check the unique reporters (Product Owners) in the Open-Source Project \n")
#Count and report the unique values

print(len(timob_df['reporter.name'].unique()))
print('\n****************************************************\n')
timob_df['reporter.name'].unique()

# %%
print("\n Check the unique creators in the Open-Source Project \n")
#Count and report the unique values

print(len(timob_df['creator.name'].unique()))
print('\n****************************************************\n')
timob_df['creator.name'].unique()

# %%
print("\n Check the total number of issues in the Open-Source Project \n")

print(timob_df['key'].count())
#timob_df[timob_df.key[0]].count()
#timob_df.count(0)

# %%
print("\n Check the total number of sprints in the Open-Source Project \n")

print(timob_df['sprint'].count())
#timob_df[timob_df.key[0]].count()
#timob_df.count(0)

# %%
print("\n******************************\n")
print("Printing Project Unique Story Points and their Count: \n")
print(timob_df['storypoints'].value_counts())

#print("\n******************************\n")
#print("Printing the row (issue) where the number of story points is 15 \n")
#print(timob_df.loc[timob_df['storypoints'] == 15])

# %%
print("\n Exploring the data field: Created, i.e. date when the issues in this project were created. \n")
print(timob_df['created'].head(1))
print(timob_df['created'].value_counts())

# %%
print("\n Exploring the data field: Resolutiondate, i.e. date when the issues in this project were resolved. \n")
print(len(timob_df['resolutiondate']))
print(timob_df['resolutiondate'].tail(5))
print(timob_df['resolutiondate'].value_counts())

print('\n\n')
timob_df['resolutiondate'].tail(20)

# %%
print("\n Exploring the data field: Updated, i.e. date when the issues in this project were updated. \n")
print(timob_df['updated'])
print(timob_df['updated'].value_counts())

# %% [markdown]
# ## **Working with DATES!**

# %%
timob_df.info()

# %%
#Converting the dates to pandas datetime format, which will be easier to process.

timob_df['created'] = pd.to_datetime(timob_df.created)

# %%
timob_df.head()

# %%
timob_df.dtypes

# %%
timob_df.created.dt.dayofyear

# %%
timob_df['resolutiondate'] = pd.to_datetime(timob_df.resolutiondate)

# %%
timob_df.resolutiondate.dt.dayofyear
