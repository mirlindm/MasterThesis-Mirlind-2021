# %% [markdown]
# ## **Should I remove issues having no developers?**

# %% [markdown]
# ## **Upload the dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bf9cd04f-2afd-41ed-a9b9-7dbc2dde6c42" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bf9cd04f-2afd-41ed-a9b9-7dbc2dde6c42">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mesos_dataframe.csv to mesos_dataframe.csv

# %% [markdown]
# ## **Reading the dataset. Providing initial descriptives for the project's data. Before cleaning stage.**

# %%
import pandas as pd

mesos_df = pd.read_csv("mesos_dataframe.csv")

print("\n******************************\n")
print("Printing Dataset Initial Shape: \n")
print(mesos_df.shape)
print("\n******************************\n")
print("Printing Dataset Initial Descriptives: \n")
print(mesos_df.describe())
print("\n******************************\n")
print("Printing Dataset Information: \n")
print(mesos_df.info())
# Out:
# ******************************
#
# Printing Dataset Initial Shape:
#
# (2304, 24)
#
# ******************************
#
# Printing Dataset Initial Descriptives:
#
#           status.id  watches.watchCount  storypoints
# count   2304.000000         2304.000000  2304.000000
# mean    1355.932726            3.088976     3.517166
# std     3421.059332            2.611372     2.643952
# min        1.000000            0.000000     0.000000
# 25%        5.000000            2.000000     2.000000
# 50%        5.000000            2.000000     3.000000
# 75%        5.000000            4.000000     5.000000
# max    10020.000000           37.000000    40.000000
#
# ******************************
#
# Printing Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2304 entries, 0 to 2303
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
# ...

# %%
print("\n Check the number of total missing values in the Open-Source Project \n")
#To-DO
print(mesos_df.isnull())
print("\n Check the data fields that contain missing values in the Open-Source Project \n")
#To-DO
print(mesos_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(mesos_df.isnull().sum().sum())
# Out:
#  Check the number of total missing values in the Open-Source Project
#
#       assignee.name  components  created  ...  storypoints  project  sprint
# 0             False       False    False  ...        False    False    True
# 1             False       False    False  ...        False    False    True
# 2             False       False    False  ...        False    False    True
# 3              True       False    False  ...        False    False    True
# 4             False       False    False  ...        False    False    True
# ...             ...         ...      ...  ...          ...      ...     ...
# 2299          False       False    False  ...        False    False   False
# 2300          False       False    False  ...        False    False    True
# 2301          False       False    False  ...        False    False   False
# 2302          False       False    False  ...        False    False   False
# ...

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses Before Cleaning the Data**

# %%
print("Number of sprints: \n")
print(mesos_df.sprint.nunique())
print(mesos_df.sprint.unique())
print('\n\n')
print(len(mesos_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 70
# [nan 'Mesosphere Sprint 34' 'Mesosphere Sprint 33' 'Mesosphere Sprint 32'
#  'Mesosphere Sprint 31' 'Mesosphere Sprint 30' 'Mesosphere Sprint 29'
#  'Mesosphere Sprint 28' 'Mesosphere Sprint 27' 'Mesosphere Sprint 26'
#  'Mesosphere Sprint 24' 'Mesosphere Sprint 25' 'Mesosphere Sprint 23'
#  'Mesosphere Sprint 22' 'Mesosphere Sprint 21' 'Mesosphere Sprint 20'
#  'Twitter Mesos Q3 Sprint 6' 'Mesosphere Sprint 19'
#  'Twitter Mesos Q3 Sprint 5' 'Mesosphere Sprint 18'
#  'Twitter Mesos Q3 Sprint 4' 'Mesosphere Sprint 17'
#  'Twitter Mesos Q3 Sprint 3' 'Mesosphere Sprint 16'
#  'Twitter Mesos Q3 Sprint 2' 'Mesosphere Sprint 15'
#  'Twitter Mesos Q3 Sprint 1' 'Mesosphere Sprint 14' 'Mesosphere Sprint 13'
#  'Twitter Mesos Q2 Sprint 6' 'Twitter Mesos Q2 Sprint 5'
#  'Mesosphere Sprint 12' 'Twitter Q2 Sprint 3' 'Mesosphere Sprint 11'
#  'Mesosphere Sprint 10' 'Twitter Q2 Sprint 3 - 5/11' 'Twitter Q2 Sprint 2'
# ...

# %%
print("Number of issues: \n")
print(mesos_df.key.nunique())
print(mesos_df.key.unique())
print('\n\n')
print(len(mesos_df.key.unique()))

# %%
print("Number of developers: \n")
print(mesos_df['assignee.name'].nunique())
print('\n\n')
print(mesos_df['assignee.name'].unique())
print('\n\n')
print(len(mesos_df['assignee.name'].unique()))

# %%
print("Number of reporters: \n")
print(mesos_df['reporter.name'].nunique())
print('\n\n')
print(mesos_df['reporter.name'].unique())
print('\n\n')
print(len(mesos_df['reporter.name'].unique()))

# %%
print("Number of issue status: \n")
print(mesos_df['status.name'].nunique())
print('\n\n')
print(mesos_df['status.name'].unique())
print('\n\n')
print(len(mesos_df['status.name'].unique()))

# %% [markdown]
# ## **Exploring the dataset's columns and their missing values! *Before cleaning stage.**

# %%
print(f'There are {len(mesos_df.columns)} columns in the dataset.')
print("\n******************************\n")
print("Printing Dataset Columns Below: \n")
print(mesos_df.columns)

# %%
print('Printing some data from the dataset for ilustration purpose: \n')
mesos_df.head()

# %%
# Checking for missing values within the data fields before cleaning the data!

print(f"\nThere are: {mesos_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {mesos_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {mesos_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {mesos_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {mesos_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {mesos_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {mesos_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {mesos_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {mesos_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {mesos_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# # **Cleaning the dataset**

# %% [markdown]
# ## **1. Removing unnecessary and useless data fields!**

# %%
# Data cleaning steps

# Remove the unwanted columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount.

mesos_df.drop(columns=['components', 'fixVersions', 'issuetype.subtask', 'versions', 'watches.watchCount', 'resolution.description', 'resolution.name'], inplace = True)

print("\n Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset! \n")

print(f'\n There are now {len(mesos_df.columns)} columns in the dataset.\n')
print(f"\n Printing Data Fields Below: \n {mesos_df.columns} \n")
# Out:
#  Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset!
#
#
#  There are now 17 columns in the dataset.
#
#
#  Printing Data Fields Below:
#  Index(['assignee.name', 'created', 'creator.name', 'description',
#        'issuetype.name', 'priority.name', 'reporter.name', 'resolutiondate',
#        'status.id', 'status.name', 'status.statusCategory.name', 'summary',
#        'updated', 'key', 'storypoints', 'project', 'sprint'],
#       dtype='object')

# %%
print("Printing the new dataset: \n")

mesos_df.head()

# %% [markdown]
# ##**2. Removing the duplicate issues, only keeping one instance of them! Removing isses that have same issue_identifier (KEY)!**

# %%
#Data cleaning steps

# 1.  Remove duplicated issue reports: it doesn't make sense to have ISSUE REPORTS that 
#     have exactly the same content since it was probably a mistake from data input.

# Select all duplicate rows based on column: key
duplicateRowsDF = mesos_df[mesos_df.duplicated(['key'])]
print(f"\nThere are: {len(duplicateRowsDF)} issue duplicates! \n")


print(f"{mesos_df['key'].value_counts()} \n\n")
print(f"Count of column: key, before cleaning is: {mesos_df['key'].count()}\n\n")
print(f"Printing some example issues that have the same identifier: \n")
print(mesos_df.loc[mesos_df['key'] == 'MESOS-2110'])
# print(mesos_df.loc[mesos_df['key'] == 'XD-371'])
# print(mesos_df.loc[mesos_df['key'] == 'XD-375'])
# Out:
# There are: 832 issue duplicates!
#
# MESOS-1913    13
# MESOS-2108    13
# MESOS-2110    13
# MESOS-2085    13
# MESOS-2069    12
#               ..
# MESOS-3307     1
# MESOS-1784     1
# MESOS-3976     1
# MESOS-2547     1
# MESOS-4527     1
# Name: key, Length: 1472, dtype: int64
#
#
# Count of column: key, before cleaning is: 2304
#
#
# Printing some example issues that have the same identifier:
#
#      assignee.name  ...                         sprint
# 1871    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1872    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1873    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1874    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1875    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1876    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1877    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1878    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# 1879    adam-mesos  ...  Mesosphere Q4 Sprint 3 - 12/7
# ...

# %%
# Continuation from previous cell

# Select all duplicate rows based on one column
#duplicateRowsDF = mesos_df[mesos_df.duplicated(['key'])]
#print(f"\n There are: {len(duplicateRowsDF)} issue duplicates! \n")

#print('\n*************************************************\n')

# Here I am dropping all duplicates, while only keeping the first instance!
mesos_df = mesos_df.drop_duplicates(subset='key', keep='first')

print(f"Count of column: key, after cleaning is: {mesos_df['key'].count()}\n\n")
print(f"{mesos_df['key'].value_counts()}\n\n")
print(mesos_df.loc[mesos_df['key'] == 'XD-1507'])
print(mesos_df.loc[mesos_df['key'] == 'XD-371'])
print(mesos_df.loc[mesos_df['key'] == 'XD-375'])


# Here I check for duplicate rows based on all columns, 
# i.e. rows where all columns have same values. 
duplicated = mesos_df[mesos_df.duplicated()]
print(f"\nFinally, there are: {len(duplicated)} duplicates")
# Out:
# Count of column: key, after cleaning is: 1472
#
#
# MESOS-4926    1
# MESOS-4047    1
# MESOS-4383    1
# MESOS-4108    1
# MESOS-5139    1
#              ..
# MESOS-1396    1
# MESOS-2860    1
# MESOS-1913    1
# MESOS-4314    1
# MESOS-4678    1
# Name: key, Length: 1472, dtype: int64
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **3. Removing issues that do not have a creator.name recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty creator field. by default, 
#     all issues have to have a creator in JIRA

print(f"Count of column: creator.name, before cleaning is: {mesos_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name before cleaning, is: {mesos_df['creator.name'].isnull().sum()}. \n\n\n\n")

mesos_df.dropna(subset = ["creator.name"], inplace=True)

print(f"Count of column: creator.name, after cleaning is: {mesos_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name after cleaning, is: {mesos_df['creator.name'].isnull().sum()}. \n\n")

print(mesos_df['creator.name'].value_counts())

print('\n\n')
print(mesos_df.loc[(mesos_df['creator.name'] == '')])
print('\n\n')
mesos_df.loc[(mesos_df['creator.name'].isnull())]
# Out:
# Count of column: creator.name, before cleaning is: 1472
#
# Count of missing values in the field: creator.name before cleaning, is: 0.
#
#
#
#
# Count of column: creator.name, after cleaning is: 1472
#
# Count of missing values in the field: creator.name after cleaning, is: 0.
#
#
# vinodkone                     133
# jieyu                         104
# bmahler                        81
# kaysoky                        80
# alexr                          63
#                              ...
# gabriel.hartmann@gmail.com      1
# lins05                          1
# meatmanek                       1
# mesosmike                       1
# mrbrowning                      1
# Name: creator.name, Length: 112, dtype: int64
#
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# ...

# %% [markdown]
# ## **4. Removing empty issues, i.e. issues that do not have a description and summary.**

# %%
#Data cleaning steps

# 3.  issue reports with empty title or body: 
#     these are probably data input errors or tests, meaningless reports. 

print(f"Count of column: key, before removing issues with no description is: {mesos_df['key'].count()}\n\n")
print(f"\n There are: {mesos_df['description'].isnull().sum()}  missing values in the DESCRIPTION field! \n")
print(f"\n There are: {mesos_df['summary'].isnull().sum()}  missing values in the SUMMARY field! \n")

#mesos_df[(mesos_df['issuetype.name'].isnull())&mesos_df['description'].isnull()&mesos_df['summary'].isnull()]
#mesos_df[(mesos_df['issuetype.name'].isnull())|mesos_df['description'].isnull()|mesos_df['summary'].isnull()].head(150)
# Out:
# Count of column: key, before removing issues with no description is: 1472
#
#
#
#  There are: 107  missing values in the DESCRIPTION field!
#
#
#  There are: 0  missing values in the SUMMARY field!

# %%
mesos_df.dropna(subset=['description'], inplace=True)
print(f"Count of column: key, after removing issues with no description is: {mesos_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description is: 1365

# %%
mesos_df.dropna(subset=['description', 'summary'], inplace=True)
print(f"Count of column: key, after removing issues with no description (summary too) is: {mesos_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description (summary too) is: 1365

# %% [markdown]
# ## **5. Removing issues that do not have a ASSIGNEE.NAME recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty asignee.name field.

print(f"Count of column: assignee.name, before cleaning is: {mesos_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name before cleaning, is: {mesos_df['assignee.name'].isnull().sum()}. \n\n\n\n")

#mesos_df.dropna(subset = ["assignee.name"], inplace=True)

print(f"Count of column: assignee.name, after cleaning is: {mesos_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name after cleaning, is: {mesos_df['assignee.name'].isnull().sum()}. \n\n")

print(mesos_df['assignee.name'].value_counts())
print('\n\n')
print(mesos_df['assignee.name'].unique())
print('\n\n')
print(mesos_df.loc[(mesos_df['assignee.name'] == '')])
print('\n\n')
mesos_df.loc[(mesos_df['assignee.name'].isnull())]

# %% [markdown]
# # **After Cleaning the Data**

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses After Cleaning the Data**

# %%
print("Number of sprints: \n")
print(mesos_df.sprint.nunique())
print(mesos_df.sprint.unique())
print('\n\n')
print(len(mesos_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 70
# [nan 'Mesosphere Sprint 34' 'Mesosphere Sprint 33' 'Mesosphere Sprint 32'
#  'Mesosphere Sprint 31' 'Mesosphere Sprint 30' 'Mesosphere Sprint 29'
#  'Mesosphere Sprint 28' 'Mesosphere Sprint 27' 'Mesosphere Sprint 26'
#  'Mesosphere Sprint 24' 'Mesosphere Sprint 25' 'Mesosphere Sprint 23'
#  'Mesosphere Sprint 22' 'Mesosphere Sprint 21' 'Mesosphere Sprint 20'
#  'Twitter Mesos Q3 Sprint 6' 'Mesosphere Sprint 19'
#  'Twitter Mesos Q3 Sprint 5' 'Mesosphere Sprint 18'
#  'Twitter Mesos Q3 Sprint 4' 'Mesosphere Sprint 17'
#  'Twitter Mesos Q3 Sprint 3' 'Mesosphere Sprint 16'
#  'Twitter Mesos Q3 Sprint 2' 'Mesosphere Sprint 15'
#  'Twitter Mesos Q3 Sprint 1' 'Mesosphere Sprint 14' 'Mesosphere Sprint 13'
#  'Twitter Mesos Q2 Sprint 6' 'Twitter Mesos Q2 Sprint 5'
#  'Mesosphere Sprint 12' 'Twitter Q2 Sprint 3' 'Mesosphere Sprint 11'
#  'Mesosphere Sprint 10' 'Twitter Q2 Sprint 3 - 5/11' 'Twitter Q2 Sprint 2'
# ...

# %%
print("Number of issues: \n")
print(mesos_df.key.nunique())
print(mesos_df.key.unique())
print('\n\n')
print(len(mesos_df.key.unique()))
# Out:
# Number of issues:
#
# 1365
# ['MESOS-5338' 'MESOS-5337' 'MESOS-5336' ... 'MESOS-343' 'MESOS-336'
#  'MESOS-313']
#
#
#
# 1365

# %%
print("Number of developers: \n")
print(mesos_df['assignee.name'].nunique())
print('\n\n')
print(mesos_df['assignee.name'].unique())
print('\n\n')
print(len(mesos_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 74
#
#
#
# ['js84' nan 'gradywang' 'a10gupta' 'gyliu' 'lins05' 'qianzhang' 'jieyu'
#  'kaysoky' 'jojy' 'anandmazumdar' 'nfnt' 'jvanremoortere' 'greggomann'
#  'gilbert' 'vinodkone' 'janisz' 'klueska' 'alexr' 'mcypark' 'yongtang'
#  'karya' 'bbannier' 'avinash@mesosphere.io' 'zhitao' 'arojas' 'neilc'
#  'chenzhiwei' 'jlarriba' 'dongdong' 'haosdent@gmail.com' 'guoger'
#  'hausdorff' 'klaus1982' 'mrbrowning' 'tillt' 'anindya.sinha' 'magedm'
#  'bernd-mesos' 'tnachen' 'hartem' 'qiujian' 'jjanco' 'bmahler'
#  'SteveNiemitz' 'jamespeach' 'ijimenez' 'marco-mesos' 'mchadha' 'chzhcn'
#  'pbrett' 'xujyan' 'tanderegg' 'wangcong' 'nnielsen' 'chenlily' 'jdef'
#  'benjaminhindman' 'Bartek Plotka' 'idownes' 'balamark' 'wickman'
#  'lackita' 'bschang' 'adam-mesos' 'jvanz' 'darroyo' 'dhamon'
#  'vaibhavkhanduja' 'JamesYongQiaoWang' 'jklucar' 'nekto0n' 'cmaloney'
#  'alexandra.sava' 'tstclair']
#
#
#
# 75

# %%
print("Number of reporters: \n")
print(mesos_df['reporter.name'].nunique())
print('\n\n')
print(mesos_df['reporter.name'].unique())
print('\n\n')
print(len(mesos_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 110
#
#
#
# ['js84' 'adam-mesos' 'greggomann' 'gyliu' 'jieyu' 'avinash@mesosphere.io'
#  'jojy' 'anandmazumdar' 'nfnt' 'jvanremoortere' 'gilbert' 'vinodkone'
#  'janisz' 'kaysoky' 'klueska' 'alexr' 'neilc' 'mcypark' 'karya'
#  'qianzhang' 'arojas' 'chenzhiwei' 'clehene' 'jlarriba' 'hartem'
#  'dongdong' 'cmaloney' 'zhitao' 'bbannier' 'skonto' 'bernd-mesos' 'lins05'
#  'mrbrowning' 'pawanufl' 'hausdorff' 'bmahler' 'ijimenez' 'mgummelt'
#  'tillt' 'philwinder' 'klaus1982' 'ssk2hd' 'gradywang' 'woggle'
#  'JTCunning' 'tnachen' 'bydga' 'gabriel.hartmann@gmail.com' 'mandoskippy'
#  'sargun' 'SteveNiemitz' 'JamesYongQiaoWang' 'marco-mesos' 'BenWhitehead'
#  'jamespeach' 'aquamatthias' 'stevenschlansker' 'frankscholten' 'rdifazio'
#  'mchadha' 'bernadinm' 'bobrik' 'maximk' 'radekg' 'chzhcn' 'pbrett'
#  'flx42' 'haosdent@gmail.com' 'xujyan' 'wfarner' 'neunhoef' 'meatmanek'
#  'wangcong' 'nnielsen' 'jamesmulcahy' 'benjaminhindman' 'chenlily' 'sttts'
# ...

# %% [markdown]
# ## **Exploring the dataset after cleaning (General Descriptives, etc.)**

# %%
print("\n******************************\n")
print("Printing Dataset Shape After Cleaning: \n")
print(mesos_df.shape)
print("\n******************************\n")
print("Printing Dataset Descriptives After Cleaning: \n")
print(mesos_df.describe())
print("\n******************************\n")
print("Printing Dataset Information After Cleaning: \n")
print(mesos_df.info())

# %% [markdown]
# ## **Analyzing the cleaned data below (Missing Values)**

# %%
print("\nCheck the number of total missing values in the Open-Source Project \n")
print(mesos_df.isnull())
print("\n\n******************************\n")
print("\nCheck the data fields that contain missing values in the Open-Source Project \n")
print(mesos_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(mesos_df.isnull().sum().sum())

# %%
# Checking for missing values after cleaning the data!

print(f"\nThere are: {mesos_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {mesos_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {mesos_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {mesos_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {mesos_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {mesos_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {mesos_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {mesos_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {mesos_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {mesos_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# ## **Checking for Scrum Rules. After cleaning stage**

# %%
print("\n Check the unique developers (usernames) in the Open-Source Project \n")
#Count and report the unique values

print(len(mesos_df['assignee.name'].unique()))
print('\n****************************************************\n')
mesos_df['assignee.name'].unique()

# %%
print("\n Check the unique reporters (Product Owners) in the Open-Source Project \n")
#Count and report the unique values

print(len(mesos_df['reporter.name'].unique()))
print('\n****************************************************\n')
mesos_df['reporter.name'].unique()

# %%
print("\n Check the unique creators in the Open-Source Project \n")
#Count and report the unique values

print(len(mesos_df['creator.name'].unique()))
print('\n****************************************************\n')
mesos_df['creator.name'].unique()

# %%
print("\n Check the total number of issues in the Open-Source Project \n")

print(mesos_df['key'].count())
#mesos_df[mesos_df.key[0]].count()
#mesos_df.count(0)

# %%
print("\n Check the total number of sprints in the Open-Source Project \n")

print(mesos_df['sprint'].count())
#mesos_df[mesos_df.key[0]].count()
#mesos_df.count(0)

# %%
print("\n******************************\n")
print("Printing Project Unique Story Points and their Count: \n")
print(mesos_df['storypoints'].value_counts())

#print("\n******************************\n")
#print("Printing the row (issue) where the number of story points is 15 \n")
#print(mesos_df.loc[mesos_df['storypoints'] == 15])

# %%
print("\n Exploring the data field: Created, i.e. date when the issues in this project were created. \n")
print(mesos_df['created'].head(1))
print(mesos_df['created'].value_counts())

# %%
print("\n Exploring the data field: Resolutiondate, i.e. date when the issues in this project were resolved. \n")
print(len(mesos_df['resolutiondate']))
print(mesos_df['resolutiondate'].tail(5))
print(mesos_df['resolutiondate'].value_counts())

print('\n\n')
mesos_df['resolutiondate'].tail(20)

# %%
print("\n Exploring the data field: Updated, i.e. date when the issues in this project were updated. \n")
print(mesos_df['updated'])
print(mesos_df['updated'].value_counts())

# %% [markdown]
# ## **Working with DATES!**

# %%
mesos_df.info()

# %%
#Converting the dates to pandas datetime format, which will be easier to process.

mesos_df['created'] = pd.to_datetime(mesos_df.created)

# %%
mesos_df.head()

# %%
mesos_df.dtypes

# %%
mesos_df.created.dt.dayofyear

# %%
mesos_df['resolutiondate'] = pd.to_datetime(mesos_df.resolutiondate)

# %%
mesos_df.resolutiondate.dt.dayofyear
