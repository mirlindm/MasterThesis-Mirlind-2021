# %% [markdown]
# ## **Upload the dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d5c0e7a4-576d-496a-aa9f-29049ed70c09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5c0e7a4-576d-496a-aa9f-29049ed70c09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving tistud_dataframe.csv to tistud_dataframe.csv

# %% [markdown]
# ## **Reading the dataset. Providing initial descriptives for the project's data. Before cleaning stage.**

# %%
import pandas as pd

tistud_df = pd.read_csv("tistud_dataframe.csv")

print("\n******************************\n")
print("Printing Dataset Initial Shape: \n")
print(tistud_df.shape)
print("\n******************************\n")
print("Printing Dataset Initial Descriptives: \n")
print(tistud_df.describe())
print("\n******************************\n")
print("Printing Dataset Information: \n")
print(tistud_df.info())
# Out:
# ******************************
#
# Printing Dataset Initial Shape:
#
# (2879, 24)
#
# ******************************
#
# Printing Dataset Initial Descriptives:
#
#           status.id  watches.watchCount  storypoints
# count   2879.000000         2879.000000  2873.000000
# mean      12.527614            2.396318     5.731291
# std      263.457812            1.938850     4.325322
# min        1.000000            0.000000     1.000000
# 25%        6.000000            1.000000     3.000000
# 50%        6.000000            2.000000     5.000000
# 75%        6.000000            3.000000     8.000000
# max    10003.000000           18.000000   144.000000
#
# ******************************
#
# Printing Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2879 entries, 0 to 2878
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
# ...

# %%
print("\n Check the number of total missing values in the Open-Source Project \n")
#To-DO
print(tistud_df.isnull())
print("\n Check the data fields that contain missing values in the Open-Source Project \n")
#To-DO
print(tistud_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(tistud_df.isnull().sum().sum())

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses Before Cleaning the Data**

# %%
print("Number of sprints: \n")
#tistud_df.sprint.nunique()
print(tistud_df.sprint.unique())
print('\n\n')
print(len(tistud_df.sprint.unique()))
# Out:
# Number of sprints:
#
# [nan '2012 Sprint 18' '2012 Sprint 19' '2012 Sprint 25' '2012 Sprint 17'
#  '2012 Sprint 20' '2012 Sprint 23' '2012 Sprint 24' '2012 Sprint 16'
#  '2013 Sprint 13' '2013 Sprint 12' '2012 Sprint 21' '2012 Sprint 15'
#  '2013 Sprint 01' '2013 Sprint 20' '2012 Sprint 22' '2012 Sprint 14'
#  '2012 Sprint 13' '2012 Sprint 12' '2012 Sprint 11' '2012 Sprint 10'
#  '2013 Sprint 03' '2013 Sprint 17' '2012 Sprint 09' '2012 Sprint 08'
#  '2012 Sprint 07' '2012 Sprint 06' '2012 Sprint 05' '2012 Sprint 04'
#  '2012 Sprint 03' '2013 Sprint 14' '2012 Sprint 02' '2013 Sprint 08'
#  '2014 Sprint 01' '2014 Sprint 07' '2014 Sprint 08' '2014 Sprint 06'
#  '2014 Sprint 05' '2014 Sprint 04' '2014 Sprint 03' '2014 Sprint 02'
#  '2013 Sprint 26' '2013 Sprint 25' '2013 Sprint 24' '2013 Sprint 23'
#  '2013 Sprint 22' '2013 Sprint 21' '2013 Sprint 19' '2013 Sprint 18'
#  '2013 Sprint 16' '2013 Sprint 15' '2013 Sprint 11' '2013 Sprint 10'
# ...

# %%
print("Number of issues: \n")
print(tistud_df.key.nunique())
print('\n\n')
print(tistud_df.key.unique())
print('\n\n')
print(len(tistud_df.key.unique()))
# Out:
# Number of issues:
#
# 2870
#
#
#
# ['TISTUD-2160' 'TISTUD-2159' 'TISTUD-2158' ... 'TISTUD-2165' 'TISTUD-2164'
#  'TISTUD-2163']
#
#
#
# 2870

# %%
print("Number of developers: \n")
print(tistud_df['assignee.name'].nunique())
print('\n\n')
print(tistud_df['assignee.name'].unique())
print('\n\n')
print(len(tistud_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 32
#
#
#
# ['pinnamuri' 'sgibly' 'mxia' 'cwilliams' 'ingo' 'nle' 'fzadrozny' 'dhyde'
#  'cheadley' 'klindsey' 'ikucheinyk' 'sdavis' 'mstepanov' 'akulinich'
#  'nhuynh' 'ayeung' 'mculpepper' 'stephentramer' 'shastaqapaulh'
#  'jfeemster' 'pdowsett' 'thomashuelbert' 'tsmalley' 'kkolipaka' 'cng'
#  'fmiao' 'lchoudhary' 'gmathews' 'bgrantges@appcelerator.com' 'smishra'
#  'lokeshchdhry' 'miu']
#
#
#
# 32

# %%
print("Number of reporters: \n")
print(tistud_df['reporter.name'].nunique())
print('\n\n')
print(tistud_df['reporter.name'].unique())
print('\n\n')
print(len(tistud_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 192
#
#
#
# ['sgibly' 'mxia' 'ingo' 'ssekhri' 'dhyde' 'aleard' 'nle' 'kasanbekov'
#  'tlukasavage' 'oromero' 'cheadley' 'psingh' 'cwilliams' 'lokeshchdhry'
#  'tristamhorn@hotmail.com' 'jlemieux' 'anagesh' 'wluu' 'gtavridis'
#  'stephentramer' 'mpmiranda' 'corthlieb' 'bitshftr' 'jhaynie' 'dcassenti'
#  'ayeung' 'michael-fig' 'mschmulen' 'rcollazo' 'emerriman' 'sfeather'
#  'nsharma' 'jenglish' 'wkong' 'mpettiford' 'stereoket' 'ngupta'
#  'skypanther' 'thomashuelbert' 'tonylukasavage' 'pdowsett' 'cliu'
#  'phillis' 'cbarber' 'sshylaja' 'nhuynh' 'klindsey' 'jwitt' 'bhughes'
#  'billdawson' 'mstepanov' 'iotashan' 'bridgesense' 'joshroesslein'
#  'mculpepper' 'akulinich' 'herzberg' 'jalter' 'avaghti' 'kwhinnery'
#  'thumbwhere' 'mofle' 'framirez' 'cintimedia' 'egomez' 'aduboff'
#  'sagarcool89' 'dtoth' 'rblalock' 'babelfisch' 'josteinaj' 'thebrousse'
#  'tomaszj' 'mross@qtags.com' 'paulkrefta' 'rpfeiffer' 'samisdat' 'eharris'
# ...

# %%
print("Number of issue status: \n")
print(tistud_df['status.name'].nunique())
print('\n\n')
print(tistud_df['status.name'].unique())
print('\n\n')
print(len(tistud_df['status.name'].unique()))
# Out:
# Number of issue status:
#
# 6
#
#
#
# ['Reopened' 'Closed' 'Resolved' 'Open' 'In  Review' 'In Progress']
#
#
#
# 6

# %% [markdown]
# ## **Exploring the dataset's columns and their missing values! *Before cleaning stage.**

# %%
print(f'There are {len(tistud_df.columns)} columns in the dataset.')
print("\n******************************\n")
print("Printing Dataset Columns Below: \n")
print(tistud_df.columns)

# %%
print('Printing some data from the dataset for ilustration purpose: \n')
tistud_df.head()

# %%
# Checking for missing values within the data fields before cleaning the data!

print(f"\nThere are: {tistud_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {tistud_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {tistud_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {tistud_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {tistud_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {tistud_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {tistud_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {tistud_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {tistud_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {tistud_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# # **Cleaning the dataset**

# %% [markdown]
# ## **1. Removing unnecessary and useless data fields!**

# %%
# Data cleaning steps

# Remove the unwanted columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount.

tistud_df.drop(columns=['components', 'fixVersions', 'issuetype.subtask', 'versions', 'watches.watchCount', 'resolution.description', 'resolution.name'], inplace = True)

print("\n Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset! \n")

print(f'\n There are now {len(tistud_df.columns)} columns in the dataset.\n')
print(f"\n Printing Data Fields Below: \n {tistud_df.columns} \n")
# Out:
#  Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset!
#
#
#  There are now 17 columns in the dataset.
#
#
#  Printing Data Fields Below:
#  Index(['assignee.name', 'created', 'creator.name', 'description',
#        'issuetype.name', 'priority.name', 'reporter.name', 'resolutiondate',
#        'status.id', 'status.name', 'status.statusCategory.name', 'summary',
#        'updated', 'key', 'storypoints', 'project', 'sprint'],
#       dtype='object')

# %%
print("Printing the new dataset: \n")

tistud_df.head()
# Out:
# Printing the new dataset:
#   assignee.name                       created  ... project          sprint
# 0     pinnamuri  2012-08-27T16:41:44.000+0000  ...  tistud             NaN
# 1        sgibly  2012-08-27T16:37:06.000+0000  ...  tistud  2012 Sprint 18
# 2        sgibly  2012-08-27T16:25:23.000+0000  ...  tistud  2012 Sprint 18
# 3          mxia  2012-08-27T16:10:37.000+0000  ...  tistud             NaN
# 4          mxia  2012-08-27T16:08:14.000+0000  ...  tistud             NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# ##**2. Removing the duplicate issues, only keeping one instance of them! Removing isses that have same issue_identifier (KEY)!**

# %%
#Data cleaning steps

# 1.  Remove duplicated issue reports: it doesn't make sense to have ISSUE REPORTS that 
#     have exactly the same content since it was probably a mistake from data input.

# Select all duplicate rows based on column: key
duplicateRowsDF = tistud_df[tistud_df.duplicated(['key'])]
print(f"\nThere are: {len(duplicateRowsDF)} issue duplicates! \n")


print(f"{tistud_df['key'].value_counts()} \n\n")
print(f"Count of column: key, before cleaning is: {tistud_df['key'].count()}\n\n")
print(f"Printing some example issues that have the same identifier: \n")
# Out:
# There are: 0 issue duplicates!
#
# TISTUD-4490    1
# TISTUD-5241    1
# TISTUD-6822    1
# TISTUD-5981    1
# TISTUD-6737    1
# TISTUD-6851    1
# TISTUD-6904    1
# TISTUD-5679    1
# TISTUD-6435    1
# TISTUD-2917    1
# TISTUD-6316    1
# TISTUD-2017    1
# TISTUD-2169    1
# TISTUD-2156    1
# TISTUD-3806    1
# Name: key, dtype: int64
#
#
# Count of column: key, before cleaning is: 2826
#
#
# Printing some example issues that have the same identifier:

# %%
# Continuation from previous cell

# Select all duplicate rows based on one column
#duplicateRowsDF = tistud_df[tistud_df.duplicated(['key'])]
#print(f"\n There are: {len(duplicateRowsDF)} issue duplicates! \n")

#print('\n*************************************************\n')

# Here I am dropping all duplicates, while only keeping the first instance!
tistud_df = tistud_df.drop_duplicates(subset='key', keep='first')

print(f"Count of column: key, after cleaning is: {tistud_df['key'].count()}\n\n")
print(f"{tistud_df['key'].value_counts()}\n\n")


# Here I check for duplicate rows based on all columns, 
# i.e. rows where all columns have same values. 
duplicated = tistud_df[tistud_df.duplicated()]
print(f"\nFinally, there are: {len(duplicated)} duplicates")
# Out:
# Count of column: key, after cleaning is: 2870
#
#
# TISTUD-506     1
# TISTUD-1015    1
# TISTUD-6435    1
# TISTUD-2917    1
# TISTUD-6316    1
#               ..
# TISTUD-1871    1
# TISTUD-5624    1
# TISTUD-1273    1
# TISTUD-7725    1
# TISTUD-4971    1
# Name: key, Length: 2870, dtype: int64
#
#
#
# Finally, there are: 0 duplicates

# %% [markdown]
# ## **3. Removing issues that do not have a creator.name recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty creator field. by default, 
#     all issues have to have a creator in JIRA

print(f"Count of column: creator.name, before cleaning is: {tistud_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name before cleaning, is: {tistud_df['creator.name'].isnull().sum()}. \n\n\n\n")

tistud_df.dropna(subset = ["creator.name"], inplace=True)

print(f"Count of column: creator.name, after cleaning is: {tistud_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name after cleaning, is: {tistud_df['creator.name'].isnull().sum()}. \n\n")

print(tistud_df['creator.name'].value_counts())

print('\n\n')
print(tistud_df.loc[(tistud_df['creator.name'] == '')])
print('\n\n')
tistud_df.loc[(tistud_df['creator.name'].isnull())]
# Out:
# Count of column: creator.name, before cleaning is: 2826
#
# Count of missing values in the field: creator.name before cleaning, is: 0.
#
#
#
#
# Count of column: creator.name, after cleaning is: 2826
#
# Count of missing values in the field: creator.name after cleaning, is: 0.
#
#
# dhyde         379
# cwilliams     288
# mxia          277
# ingo          251
# pinnamuri     196
#              ...
# morefun         1
# yomybaby        1
# mcvendrell      1
# mofle           1
# thebrousse      1
# Name: creator.name, Length: 196, dtype: int64
#
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **4. Removing empty issues, i.e. issues that do not have a description and summary.**

# %%
#Data cleaning steps

# 3.  issue reports with empty title or body: 
#     these are probably data input errors or tests, meaningless reports. 

print(f"Count of column: key, before removing issues with no description is: {tistud_df['key'].count()}\n\n")
print(f"\n There are: {tistud_df['description'].isnull().sum()}  missing values in the DESCRIPTION field! \n")
print(f"\n There are: {tistud_df['summary'].isnull().sum()}  missing values in the SUMMARY field! \n")

#tistud_df[(tistud_df['issuetype.name'].isnull())&tistud_df['description'].isnull()&tistud_df['summary'].isnull()]
#tistud_df[(tistud_df['issuetype.name'].isnull())|tistud_df['description'].isnull()|tistud_df['summary'].isnull()].head(150)
# Out:
# Count of column: key, before removing issues with no description is: 2826
#
#
#
#  There are: 0  missing values in the DESCRIPTION field!
#
#
#  There are: 0  missing values in the SUMMARY field!

# %%
tistud_df.dropna(subset=['description'], inplace=True)
print(f"Count of column: key, after removing issues with no description is: {tistud_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description is: 2826

# %%
tistud_df.dropna(subset=['description', 'summary'], inplace=True)
print(f"Count of column: key, after removing issues with no description (summary too) is: {tistud_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description (summary too) is: 2826

# %% [markdown]
# ## **5. Removing issues that do not have a ASSIGNEE.NAME recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty asignee.name field.

print(f"Count of column: assignee.name, before cleaning is: {tistud_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name before cleaning, is: {tistud_df['assignee.name'].isnull().sum()}. \n\n\n\n")

#tistud_df.dropna(subset = ["assignee.name"], inplace=True)

print(f"Count of column: assignee.name, after cleaning is: {tistud_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name after cleaning, is: {tistud_df['assignee.name'].isnull().sum()}. \n\n")

print(tistud_df['assignee.name'].value_counts())
print('\n\n')
print(tistud_df['assignee.name'].unique())
print('\n\n')
print(tistud_df.loc[(tistud_df['assignee.name'] == '')])
print('\n\n')
tistud_df.loc[(tistud_df['assignee.name'].isnull())]

# %% [markdown]
# # **After Cleaning the Data**

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses After Cleaning the Data**

# %%
print("Number of sprints: \n")
print(tistud_df.sprint.nunique())
print(tistud_df.sprint.unique())
print('\n\n')
print(len(tistud_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 59
# [nan '2012 Sprint 18' '2012 Sprint 19' '2012 Sprint 25' '2012 Sprint 17'
#  '2012 Sprint 20' '2012 Sprint 23' '2012 Sprint 24' '2012 Sprint 16'
#  '2013 Sprint 13' '2013 Sprint 12' '2012 Sprint 21' '2012 Sprint 15'
#  '2013 Sprint 01' '2013 Sprint 20' '2012 Sprint 22' '2012 Sprint 14'
#  '2012 Sprint 13' '2012 Sprint 12' '2012 Sprint 11' '2012 Sprint 10'
#  '2013 Sprint 03' '2013 Sprint 17' '2012 Sprint 09' '2012 Sprint 08'
#  '2012 Sprint 07' '2012 Sprint 06' '2012 Sprint 05' '2012 Sprint 04'
#  '2012 Sprint 03' '2013 Sprint 14' '2012 Sprint 02' '2013 Sprint 08'
#  '2014 Sprint 01' '2014 Sprint 07' '2014 Sprint 08' '2014 Sprint 06'
#  '2014 Sprint 05' '2014 Sprint 04' '2014 Sprint 03' '2014 Sprint 02'
#  '2013 Sprint 26' '2013 Sprint 25' '2013 Sprint 24' '2013 Sprint 23'
#  '2013 Sprint 22' '2013 Sprint 21' '2013 Sprint 19' '2013 Sprint 18'
#  '2013 Sprint 16' '2013 Sprint 15' '2013 Sprint 11' '2013 Sprint 10'
# ...

# %%
print("Number of issues: \n")
print(tistud_df.key.nunique())
print('\n\n')
print(tistud_df.key.unique())
print('\n\n')
print(len(tistud_df.key.unique()))
# Out:
# Number of issues:
#
# 2826
#
#
#
# ['TISTUD-2160' 'TISTUD-2159' 'TISTUD-2158' ... 'TISTUD-2165' 'TISTUD-2164'
#  'TISTUD-2163']
#
#
#
# 2826

# %%
print("Number of developers: \n")
print(tistud_df['assignee.name'].nunique())
print('\n\n')
print(tistud_df['assignee.name'].unique())
print('\n\n')
print(len(tistud_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 31
#
#
#
# ['pinnamuri' 'sgibly' 'mxia' 'cwilliams' 'ingo' 'nle' 'fzadrozny' 'dhyde'
#  'cheadley' 'klindsey' 'ikucheinyk' 'sdavis' 'mstepanov' 'akulinich'
#  'nhuynh' 'mculpepper' 'ayeung' 'stephentramer' 'shastaqapaulh'
#  'jfeemster' 'pdowsett' 'thomashuelbert' 'tsmalley' 'kkolipaka' 'cng'
#  'fmiao' 'lchoudhary' 'gmathews' 'bgrantges@appcelerator.com' 'smishra'
#  'lokeshchdhry']
#
#
#
# 31

# %%
print("Number of reporters: \n")
print(tistud_df['reporter.name'].nunique())
print('\n\n')
print(tistud_df['reporter.name'].unique())
print('\n\n')
print(len(tistud_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 192
#
#
#
# ['sgibly' 'mxia' 'ingo' 'ssekhri' 'dhyde' 'aleard' 'nle' 'kasanbekov'
#  'tlukasavage' 'oromero' 'cheadley' 'psingh' 'cwilliams' 'lokeshchdhry'
#  'tristamhorn@hotmail.com' 'jlemieux' 'anagesh' 'wluu' 'gtavridis'
#  'stephentramer' 'mpmiranda' 'corthlieb' 'bitshftr' 'jhaynie' 'dcassenti'
#  'ayeung' 'michael-fig' 'mschmulen' 'rcollazo' 'emerriman' 'sfeather'
#  'nsharma' 'jenglish' 'wkong' 'mpettiford' 'stereoket' 'ngupta'
#  'skypanther' 'thomashuelbert' 'tonylukasavage' 'pdowsett' 'cliu'
#  'phillis' 'cbarber' 'sshylaja' 'nhuynh' 'klindsey' 'jwitt' 'bhughes'
#  'billdawson' 'iotashan' 'bridgesense' 'joshroesslein' 'mculpepper'
#  'akulinich' 'herzberg' 'jalter' 'avaghti' 'kwhinnery' 'thumbwhere'
#  'mofle' 'framirez' 'cintimedia' 'egomez' 'aduboff' 'sagarcool89' 'dtoth'
#  'rblalock' 'babelfisch' 'josteinaj' 'thebrousse' 'tomaszj'
#  'mross@qtags.com' 'paulkrefta' 'rpfeiffer' 'mstepanov' 'samisdat'
# ...

# %% [markdown]
# ## **Exploring the dataset after cleaning (General Descriptives, etc.)**

# %%
print("\n******************************\n")
print("Printing Dataset Shape After Cleaning: \n")
print(tistud_df.shape)
print("\n******************************\n")
print("Printing Dataset Descriptives After Cleaning: \n")
print(tistud_df.describe())
print("\n******************************\n")
print("Printing Dataset Information After Cleaning: \n")
print(tistud_df.info())

# %% [markdown]
# ## **Analyzing the cleaned data below (Missing Values)**

# %%
print("\nCheck the number of total missing values in the Open-Source Project \n")
print(tistud_df.isnull())
print("\n\n******************************\n")
print("\nCheck the data fields that contain missing values in the Open-Source Project \n")
print(tistud_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(tistud_df.isnull().sum().sum())

# %%
# Checking for missing values after cleaning the data!

print(f"\nThere are: {tistud_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {tistud_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {tistud_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {tistud_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {tistud_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {tistud_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {tistud_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {tistud_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {tistud_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {tistud_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# ## **Checking for Scrum Rules. After cleaning stage**

# %%
print("\n Check the unique developers (usernames) in the Open-Source Project \n")
#Count and report the unique values

print(len(tistud_df['assignee.name'].unique()))
print('\n****************************************************\n')
tistud_df['assignee.name'].unique()

# %%
print("\n Check the unique reporters (Product Owners) in the Open-Source Project \n")
#Count and report the unique values

print(len(tistud_df['reporter.name'].unique()))
print('\n****************************************************\n')
tistud_df['reporter.name'].unique()

# %%
print("\n Check the unique creators in the Open-Source Project \n")
#Count and report the unique values

print(len(tistud_df['creator.name'].unique()))
print('\n****************************************************\n')
tistud_df['creator.name'].unique()

# %%
print("\n Check the total number of issues in the Open-Source Project \n")

print(tistud_df['key'].count())
#tistud_df[tistud_df.key[0]].count()
#tistud_df.count(0)

# %%
print("\n Check the total number of sprints in the Open-Source Project \n")

print(tistud_df['sprint'].count())
#tistud_df[tistud_df.key[0]].count()
#tistud_df.count(0)

# %%
print("\n******************************\n")
print("Printing Project Unique Story Points and their Count: \n")
print(tistud_df['storypoints'].value_counts())

#print("\n******************************\n")
#print("Printing the row (issue) where the number of story points is 15 \n")
#print(tistud_df.loc[tistud_df['storypoints'] == 15])

# %%
print("\n Exploring the data field: Created, i.e. date when the issues in this project were created. \n")
print(tistud_df['created'].head(1))
print(tistud_df['created'].value_counts())

# %%
print("\n Exploring the data field: Resolutiondate, i.e. date when the issues in this project were resolved. \n")
print(len(tistud_df['resolutiondate']))
print(tistud_df['resolutiondate'].tail(5))
print(tistud_df['resolutiondate'].value_counts())

print('\n\n')
tistud_df['resolutiondate'].tail(20)

# %%
print("\n Exploring the data field: Updated, i.e. date when the issues in this project were updated. \n")
print(tistud_df['updated'])
print(tistud_df['updated'].value_counts())

# %% [markdown]
# ## **Working with DATES!**

# %%
tistud_df.info()

# %%
#Converting the dates to pandas datetime format, which will be easier to process.

tistud_df['created'] = pd.to_datetime(tistud_df.created)

# %%
tistud_df.head()

# %%
tistud_df.dtypes

# %%
tistud_df.created.dt.dayofyear

# %%
tistud_df['resolutiondate'] = pd.to_datetime(tistud_df.resolutiondate)

# %%
tistud_df.resolutiondate.dt.dayofyear
