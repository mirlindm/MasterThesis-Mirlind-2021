# %% [markdown]
# ## **Upload the dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8e41d793-ad02-4daa-988f-9b01ccb57715" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8e41d793-ad02-4daa-988f-9b01ccb57715">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mdl_dataframe.csv to mdl_dataframe.csv

# %% [markdown]
# ## **Reading the dataset. Providing initial descriptives for the project's data. Before cleaning stage.**

# %%
import pandas as pd

mdl_df = pd.read_csv("mdl_dataframe.csv")

print("\n******************************\n")
print("Printing Dataset Initial Shape: \n")
print(mdl_df.shape)
print("\n******************************\n")
print("Printing Dataset Initial Descriptives: \n")
print(mdl_df.describe())
print("\n******************************\n")
print("Printing Dataset Information: \n")
print(mdl_df.info())
# Out:
# ******************************
#
# Printing Dataset Initial Shape:
#
# (64859, 24)
#
# ******************************
#
# Printing Dataset Initial Descriptives:
#
#           status.id  watches.watchCount  storypoints
# count  64859.000000        64859.000000  1404.000000
# mean      30.394224            2.652461    13.388177
# std      500.981289            4.368582    20.942723
# min        1.000000            0.000000     0.000000
# 25%        6.000000            0.000000     3.000000
# 50%        6.000000            2.000000     5.000000
# 75%        6.000000            3.000000    13.000000
# max    10013.000000          156.000000   195.000000
#
# ******************************
#
# Printing Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64859 entries, 0 to 64858
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
# ...

# %%
print("\n Check the number of total missing values in the Open-Source Project \n")
#To-DO
print(mdl_df.isnull())
print("\n Check the data fields that contain missing values in the Open-Source Project \n")
#To-DO
print(mdl_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(mdl_df.isnull().sum().sum())
# Out:
#  Check the number of total missing values in the Open-Source Project
#
#        assignee.name  components  created  ...  storypoints  project  sprint
# 0               True       False    False  ...         True    False   False
# 1               True       False    False  ...         True    False    True
# 2               True       False    False  ...         True    False    True
# 3               True       False    False  ...         True    False    True
# 4               True       False    False  ...         True    False    True
# ...              ...         ...      ...  ...          ...      ...     ...
# 64854          False       False    False  ...         True    False    True
# 64855          False       False    False  ...         True    False    True
# 64856          False       False    False  ...         True    False    True
# 64857          False       False    False  ...         True    False    True
# ...

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses Before Cleaning the Data**

# %%
print("Number of sprints: \n")
print(mdl_df.sprint.nunique())
print(mdl_df.sprint.unique())
print('\n\n')
print(len(mdl_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 269
# ["['com.atlassian.greenhopper.service.sprint.Sprint@40c6b8aa[id=237,rapidViewId=126,state=ACTIVE,name=Moodle 3.9 - Moppies Kanban,startDate=2019-09-15T13:49:00.000Z,endDate=2019-10-31T14:49:00.000Z,completeDate=<null>,sequence=237,goal=<null>]']"
#  nan
#  "['com.atlassian.greenhopper.service.sprint.Sprint@1acb77b7[id=277,rapidViewId=142,state=ACTIVE,name=Activity Sprint 7,startDate=2020-02-17T03:31:47.824Z,endDate=2020-03-02T03:31:00.000Z,completeDate=<null>,sequence=277,goal=Get a bulk of the chooser in and prep for MoodleNet]']"
#  "['com.atlassian.greenhopper.service.sprint.Sprint@2b385788[id=279,rapidViewId=115,state=ACTIVE,name=International 3.9 - Sprint 6,startDate=2020-02-18T01:00:00.000Z,endDate=2020-03-02T13:00:00.000Z,completeDate=<null>,sequence=279,goal=]']"
# ...

# %%
print("Number of issues: \n")
print(mdl_df.key.nunique())
print(mdl_df.key.unique())
print('\n\n')
print(len(mdl_df.key.unique()))
# Out:
# Number of issues:
#
# 64795
# ['MDL-68007' 'MDL-68006' 'MDL-68005' ... 'MDL-69' 'MDL-68' 'MDL-67']
#
#
#
# 64796

# %%
print("Number of developers: \n")
print(mdl_df['assignee.name'].nunique())
print('\n\n')
print(mdl_df['assignee.name'].unique())
print('\n\n')
print(len(mdl_df['assignee.name'].unique()))

# %%
print("Number of reporters: \n")
print(mdl_df['reporter.name'].nunique())
print('\n\n')
print(mdl_df['reporter.name'].unique())
print('\n\n')
print(len(mdl_df['reporter.name'].unique()))

# %%
print("Number of issue status: \n")
print(mdl_df['status.name'].nunique())
print('\n\n')
print(mdl_df['status.name'].unique())
print('\n\n')
print(len(mdl_df['status.name'].unique()))

# %% [markdown]
# ## **Exploring the dataset's columns and their missing values! *Before cleaning stage.**

# %%
print(f'There are {len(mdl_df.columns)} columns in the dataset.')
print("\n******************************\n")
print("Printing Dataset Columns Below: \n")
print(mdl_df.columns)

# %%
print('Printing some data from the dataset for ilustration purpose: \n')
mdl_df.head()

# %%
# Checking for missing values within the data fields before cleaning the data!

print(f"\nThere are: {mdl_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {mdl_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {mdl_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {mdl_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {mdl_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {mdl_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {mdl_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {mdl_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {mdl_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {mdl_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# # **Cleaning the dataset**

# %% [markdown]
# ## **1. Removing unnecessary and useless data fields!**

# %%
# Data cleaning steps

# Remove the unwanted columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount.

mdl_df.drop(columns=['components', 'fixVersions', 'issuetype.subtask', 'versions', 'watches.watchCount', 'resolution.description', 'resolution.name'], inplace = True)

print("\n Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset! \n")

print(f'\n There are now {len(mdl_df.columns)} columns in the dataset.\n')
print(f"\n Printing Data Fields Below: \n {mdl_df.columns} \n")
# Out:
#  Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset!
#
#
#  There are now 17 columns in the dataset.
#
#
#  Printing Data Fields Below:
#  Index(['assignee.name', 'created', 'creator.name', 'description',
#        'issuetype.name', 'priority.name', 'reporter.name', 'resolutiondate',
#        'status.id', 'status.name', 'status.statusCategory.name', 'summary',
#        'updated', 'key', 'storypoints', 'project', 'sprint'],
#       dtype='object')

# %%
print("Printing the new dataset: \n")

mdl_df.head()
# Out:
# Printing the new dataset:
#   assignee.name  ...                                             sprint
# 0           NaN  ...  ['com.atlassian.greenhopper.service.sprint.Spr...
# 1           NaN  ...                                                NaN
# 2           NaN  ...                                                NaN
# 3           NaN  ...                                                NaN
# 4           NaN  ...                                                NaN
#
# [5 rows x 17 columns]

# %% [markdown]
# ##**2. Removing the duplicate issues, only keeping one instance of them! Removing isses that have same issue_identifier (KEY)!**

# %%
#Data cleaning steps

# 1.  Remove duplicated issue reports: it doesn't make sense to have ISSUE REPORTS that 
#     have exactly the same content since it was probably a mistake from data input.

# Select all duplicate rows based on column: key
duplicateRowsDF = mdl_df[mdl_df.duplicated(['key'])]
print(f"\nThere are: {len(duplicateRowsDF)} issue duplicates! \n")

#print(duplicateRowsDF)
print(f"{mdl_df['key'].value_counts()} \n\n")
print(f"Count of column: key, before cleaning is: {mdl_df['key'].count()}\n\n")
print(f"Printing some example issues that have the same identifier: \n")
#print(mdl_df.loc[mdl_df['assignee.name'] == 'jpataleta'])
# print(mdl_df.loc[mdl_df['key'] == 'XD-371'])
# print(mdl_df.loc[mdl_df['key'] == 'XD-375'])
# Out:
# There are: 63 issue duplicates!
#
# MDL-17155    1
# MDL-8339     1
# MDL-38616    1
# MDL-66925    1
# MDL-14288    1
#             ..
# MDL-35982    1
# MDL-29702    1
# MDL-67518    1
# MDL-1202     1
# MDL-26744    1
# Name: key, Length: 64795, dtype: int64
#
#
# Count of column: key, before cleaning is: 64795
#
#
# Printing some example issues that have the same identifier:

# %%
# Continuation from previous cell

# Select all duplicate rows based on one column
#duplicateRowsDF = mdl_df[mdl_df.duplicated(['key'])]
#print(f"\n There are: {len(duplicateRowsDF)} issue duplicates! \n")

#print('\n*************************************************\n')

# Here I am dropping all duplicates, while only keeping the first instance!
mdl_df = mdl_df.drop_duplicates(subset='key', keep='first')

print(f"Count of column: key, after cleaning is: {mdl_df['key'].count()}\n\n")
print(f"{mdl_df['key'].value_counts()}\n\n")
# print(mdl_df.loc[mdl_df['key'] == 'XD-1507'])
# print(mdl_df.loc[mdl_df['key'] == 'XD-371'])
# print(mdl_df.loc[mdl_df['key'] == 'XD-375'])


# Here I check for duplicate rows based on all columns, 
# i.e. rows where all columns have same values. 
duplicated = mdl_df[mdl_df.duplicated()]
print(f"\nFinally, there are: {len(duplicated)} duplicates")
# Out:
# Count of column: key, after cleaning is: 64795
#
#
# MDL-17155    1
# MDL-8339     1
# MDL-38616    1
# MDL-66925    1
# MDL-14288    1
#             ..
# MDL-35982    1
# MDL-29702    1
# MDL-67518    1
# MDL-1202     1
# MDL-26744    1
# Name: key, Length: 64795, dtype: int64
#
#
#
# Finally, there are: 0 duplicates

# %% [markdown]
# ## **3. Removing issues that do not have a creator.name recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty creator field. by default, 
#     all issues have to have a creator in JIRA

print(f"Count of column: creator.name, before cleaning is: {mdl_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name before cleaning, is: {mdl_df['creator.name'].isnull().sum()}. \n\n\n\n")

mdl_df.dropna(subset = ["creator.name"], inplace=True)

print(f"Count of column: creator.name, after cleaning is: {mdl_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name after cleaning, is: {mdl_df['creator.name'].isnull().sum()}. \n\n")

print(mdl_df['creator.name'].value_counts())

print('\n\n')
print(mdl_df.loc[(mdl_df['creator.name'] == '')])
print('\n\n')
mdl_df.loc[(mdl_df['creator.name'].isnull())]
# Out:
# Count of column: creator.name, before cleaning is: 64460
#
# Count of missing values in the field: creator.name before cleaning, is: 336.
#
#
#
#
# Count of column: creator.name, after cleaning is: 64460
#
# Count of missing values in the field: creator.name after cleaning, is: 0.
#
#
# skodak          2090
# imported        1942
# stronk7         1821
# dobedobedoh     1521
# timhunt         1518
#                 ...
# eman46             1
# nick.hood          1
# jkstiles           1
# jack.oregan        1
# larryawilson       1
# Name: creator.name, Length: 8098, dtype: int64
#
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **4. Removing empty issues, i.e. issues that do not have a description and summary.**

# %%
#Data cleaning steps

# 3.  issue reports with empty title or body: 
#     these are probably data input errors or tests, meaningless reports. 

print(f"Count of column: key, before removing issues with no description is: {mdl_df['key'].count()}\n\n")
print(f"\n There are: {mdl_df['description'].isnull().sum()}  missing values in the DESCRIPTION field! \n")
print(f"\n There are: {mdl_df['summary'].isnull().sum()}  missing values in the SUMMARY field! \n")

#mdl_df[(mdl_df['issuetype.name'].isnull())&mdl_df['description'].isnull()&mdl_df['summary'].isnull()]
#mdl_df[(mdl_df['issuetype.name'].isnull())|mdl_df['description'].isnull()|mdl_df['summary'].isnull()].head(150)
# Out:
# Count of column: key, before removing issues with no description is: 64459
#
#
#
#  There are: 1186  missing values in the DESCRIPTION field!
#
#
#  There are: 0  missing values in the SUMMARY field!

# %%
mdl_df.dropna(subset=['description'], inplace=True)
print(f"Count of column: key, after removing issues with no description is: {mdl_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description is: 63273

# %%
mdl_df.dropna(subset=['description', 'summary'], inplace=True)
print(f"Count of column: key, after removing issues with no description (summary too) is: {mdl_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description (summary too) is: 63273

# %% [markdown]
# ## **5. Removing issues that do not have a ASSIGNEE.NAME recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty asignee.name field.

print(f"Count of column: assignee.name, before cleaning is: {mdl_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name before cleaning, is: {mdl_df['assignee.name'].isnull().sum()}. \n\n\n\n")

#mdl_df.dropna(subset = ["assignee.name"], inplace=True)

print(f"Count of column: assignee.name, after cleaning is: {mdl_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name after cleaning, is: {mdl_df['assignee.name'].isnull().sum()}. \n\n")

print(mdl_df['assignee.name'].value_counts())
print('\n\n')
print(mdl_df['assignee.name'].unique())
print('\n\n')
print(mdl_df.loc[(mdl_df['assignee.name'] == '')])
print('\n\n')
mdl_df.loc[(mdl_df['assignee.name'].isnull())]

# %% [markdown]
# # **After Cleaning the Data**

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses After Cleaning the Data**

# %%
print("Number of sprints: \n")
print(mdl_df.sprint.nunique())
print(mdl_df.sprint.unique())
print('\n\n')
print(len(mdl_df.sprint.unique()))

# %%
print("Number of issues: \n")
print(mdl_df.key.nunique())
print(mdl_df.key.unique())
print('\n\n')
print(len(mdl_df.key.unique()))
# Out:
# Number of issues:
#
# 63273
# ['MDL-68007' 'MDL-68006' 'MDL-68005' ... 'MDL-69' 'MDL-68' 'MDL-67']
#
#
#
# 63274

# %%
print("Number of developers: \n")
print(mdl_df['assignee.name'].nunique())
print('\n\n')
print(mdl_df['assignee.name'].unique())
print('\n\n')
print(len(mdl_df['assignee.name'].unique()))

# %%
print("Number of reporters: \n")
print(mdl_df['reporter.name'].nunique())
print('\n\n')
print(mdl_df['reporter.name'].unique())
print('\n\n')
print(len(mdl_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 8048
#
#
#
# ['tusefomal' 'nmagill' 'lexx_koto' ... 'ursularaab' 'yositune' 'digerati']
#
#
#
# 8049

# %% [markdown]
# ## **Exploring the dataset after cleaning (General Descriptives, etc.)**

# %%
print("\n******************************\n")
print("Printing Dataset Shape After Cleaning: \n")
print(mdl_df.shape)
print("\n******************************\n")
print("Printing Dataset Descriptives After Cleaning: \n")
print(mdl_df.describe())
print("\n******************************\n")
print("Printing Dataset Information After Cleaning: \n")
print(mdl_df.info())
# Out:
# ******************************
#
# Printing Dataset Shape After Cleaning:
#
# (63274, 17)
#
# ******************************
#
# Printing Dataset Descriptives After Cleaning:
#
#           status.id  storypoints
# count  63274.000000  1403.000000
# mean      31.008866    13.397006
# std      507.202057    20.947576
# min        1.000000     0.000000
# 25%        6.000000     3.000000
# 50%        6.000000     5.000000
# 75%        6.000000    13.000000
# max    10013.000000   195.000000
#
# ******************************
#
# Printing Dataset Information After Cleaning:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63274 entries, 0 to 64858
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   assignee.name               46355 non-null  object
#  1   created                     63274 non-null  object
#  2   creator.name                63274 non-null  object
# ...

# %% [markdown]
# ## **Analyzing the cleaned data below (Missing Values)**

# %%
print("\nCheck the number of total missing values in the Open-Source Project \n")
print(mdl_df.isnull())
print("\n\n******************************\n")
print("\nCheck the data fields that contain missing values in the Open-Source Project \n")
print(mdl_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(mdl_df.isnull().sum().sum())
# Out:
# Check the number of total missing values in the Open-Source Project
#
#        assignee.name  created  creator.name  ...  storypoints  project  sprint
# 0               True    False         False  ...         True    False   False
# 1               True    False         False  ...         True    False    True
# 2               True    False         False  ...         True    False    True
# 3               True    False         False  ...         True    False    True
# 4               True    False         False  ...         True    False    True
# ...              ...      ...           ...  ...          ...      ...     ...
# 64854          False    False         False  ...         True    False    True
# 64855          False    False         False  ...         True    False    True
# 64856          False    False         False  ...         True    False    True
# 64857          False    False         False  ...         True    False    True
# ...

# %%
# Checking for missing values after cleaning the data!

print(f"\nThere are: {mdl_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {mdl_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {mdl_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {mdl_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {mdl_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {mdl_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {mdl_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {mdl_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {mdl_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {mdl_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# ## **Checking for Scrum Rules. After cleaning stage**

# %%
print("\n Check the unique developers (usernames) in the Open-Source Project \n")
#Count and report the unique values

print(len(mdl_df['assignee.name'].unique()))
print('\n****************************************************\n')
mdl_df['assignee.name'].unique()

# %%
print("\n Check the unique reporters (Product Owners) in the Open-Source Project \n")
#Count and report the unique values

print(len(mdl_df['reporter.name'].unique()))
print('\n****************************************************\n')
mdl_df['reporter.name'].unique()

# %%
print("\n Check the unique creators in the Open-Source Project \n")
#Count and report the unique values

print(len(mdl_df['creator.name'].unique()))
print('\n****************************************************\n')
mdl_df['creator.name'].unique()

# %%
print("\n Check the total number of issues in the Open-Source Project \n")

print(mdl_df['key'].count())
#mdl_df[mdl_df.key[0]].count()
#mdl_df.count(0)

# %%
print("\n Check the total number of sprints in the Open-Source Project \n")

print(mdl_df['sprint'].count())
#mdl_df[mdl_df.key[0]].count()
#mdl_df.count(0)

# %%
print("\n******************************\n")
print("Printing Project Unique Story Points and their Count: \n")
print(mdl_df['storypoints'].value_counts())

#print("\n******************************\n")
#print("Printing the row (issue) where the number of story points is 15 \n")
#print(mdl_df.loc[mdl_df['storypoints'] == 15])

# %%
print("\n Exploring the data field: Created, i.e. date when the issues in this project were created. \n")
print(mdl_df['created'].head(1))
print(mdl_df['created'].value_counts())

# %%
print("\n Exploring the data field: Resolutiondate, i.e. date when the issues in this project were resolved. \n")
print(len(mdl_df['resolutiondate']))
print(mdl_df['resolutiondate'].tail(5))
print(mdl_df['resolutiondate'].value_counts())

print('\n\n')
mdl_df['resolutiondate'].tail(20)

# %%
print("\n Exploring the data field: Updated, i.e. date when the issues in this project were updated. \n")
print(mdl_df['updated'])
print(mdl_df['updated'].value_counts())

# %% [markdown]
# ## **Working with DATES!**

# %%
mdl_df.info()

# %%
#Converting the dates to pandas datetime format, which will be easier to process.

mdl_df['created'] = pd.to_datetime(mdl_df.created)

# %%
mdl_df.head()

# %%
mdl_df.dtypes

# %%
mdl_df.created.dt.dayofyear

# %%
mdl_df['resolutiondate'] = pd.to_datetime(mdl_df.resolutiondate)

# %%
mdl_df.resolutiondate.dt.dayofyear
