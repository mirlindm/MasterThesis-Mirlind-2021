# %% [markdown]
# ## **Upload the dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-abf80587-e581-4f76-8851-4ed863f252aa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abf80587-e581-4f76-8851-4ed863f252aa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dnn_dataframe.csv to dnn_dataframe.csv

# %% [markdown]
# ## **Reading the dataset. Providing initial descriptives for the project's data. Before cleaning stage.**

# %%
import pandas as pd

dnn_df = pd.read_csv("dnn_dataframe.csv")

print("\n******************************\n")
print("Printing Dataset Initial Shape: \n")
print(dnn_df.shape)
print("\n******************************\n")
print("Printing Dataset Initial Descriptives: \n")
print(dnn_df.describe())
print("\n******************************\n")
print("Printing Dataset Information: \n")
print(dnn_df.info())
# Out:
# ******************************
#
# Printing Dataset Initial Shape:
#
# (3328, 24)
#
# ******************************
#
# Printing Dataset Initial Descriptives:
#
#           status.id  watches.watchCount  storypoints
# count   3328.000000         3328.000000  3328.000000
# mean      39.190505            4.065505     2.323197
# std      579.404421            1.897566     2.453263
# min        1.000000            0.000000     0.000000
# 25%        6.000000            3.000000     1.000000
# 50%        6.000000            4.000000     2.000000
# 75%        6.000000            5.000000     3.000000
# max    10133.000000           13.000000   100.000000
#
# ******************************
#
# Printing Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3328 entries, 0 to 3327
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
# ...

# %%
print("\n Check the number of total missing values in the Open-Source Project \n")
#To-DO
print(dnn_df.isnull())
print("\n Check the data fields that contain missing values in the Open-Source Project \n")
#To-DO
print(dnn_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(dnn_df.isnull().sum().sum())
# Out:
#  Check the number of total missing values in the Open-Source Project
#
#       assignee.name  components  created  ...  storypoints  project  sprint
# 0              True       False    False  ...        False    False   False
# 1              True       False    False  ...        False    False   False
# 2              True       False    False  ...        False    False   False
# 3              True       False    False  ...        False    False   False
# 4              True       False    False  ...        False    False   False
# ...             ...         ...      ...  ...          ...      ...     ...
# 3323           True       False    False  ...        False    False   False
# 3324           True       False    False  ...        False    False   False
# 3325           True       False    False  ...        False    False   False
# 3326           True       False    False  ...        False    False   False
# ...

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses Before Cleaning the Data**

# %%
print("Number of sprints: \n")
print(dnn_df.sprint.nunique())
print(dnn_df.sprint.unique())
print('\n\n')
print(len(dnn_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 103
# ['Sprint 2' 'Sprint 1' nan '7.2.2 Sprint 2' 'Sprint 0' '7.3.0 Sprint 6'
#  '7.2.1 Sprint 4' '7.2.2 Sprint 3' '7.3.0 Sprint 5' '7.3.0 Sprint 2'
#  '7.2.1 Sprint 3' 'Platform 8.0 - Sprint 14' 'Sprint 3' '7.2.1 Sprint 2'
#  'Sprint 4' '7.3.0 Sprint 1' 'Sprint 6' '7.3.1 Sprint 2'
#  '7.2.2 Sprint 1 (Platform)' '7.3.0 Sprint 4' 'Sprint 5'
#  'Content 9.0 - Sprint 3' 'Platform 8.1 - Sprint 2'
#  'Platform 8.1 - Sprint 4' 'Engage 9.0 - Sprint 2'
#  'Platform 8.1 - Sprint 1' 'Content 8.4 - Sprint 4 (CF)'
#  'Content 9.0 - Sprint 1' 'Platform 8.0.1 - Sprint 4 (CF)'
#  'Platform 8.0.1 - Sprint 3' 'Platform 8.0.1 - Sprint 2'
#  'Content 8.4 - Sprint 1' 'Platform 8.0.1 - Sprint 1'
#  'Content 8.3 - Sprint 4' 'Platform 8.0 - Sprint 15 (FF)'
#  'Content 8.3 - Sprint 5 (FF)' 'Engage 8.3.0 - Sprint 5 (FF)'
#  'Platform 8.0 - Sprint 13' 'Platform 8.0 - Sprint 12'
#  'Platform 8.0 - Sprint 11' 'Platform 8.0 - Sprint 11 QA'
# ...

# %%
print("Number of issues: \n")
print(dnn_df.key.nunique())
print(dnn_df.key.unique())
print('\n\n')
print(len(dnn_df.key.unique()))
# Out:
# Number of issues:
#
# 1894
# ['DNN-27698' 'DNN-27696' 'DNN-27688' ... 'DNN-2949' 'DNN-2941' 'DNN-1']
#
#
#
# 1894

# %%
print("Number of developers: \n")
print(dnn_df['assignee.name'].nunique())
print('\n\n')
print(dnn_df['assignee.name'].unique())
print('\n\n')
print(len(dnn_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 12
#
#
#
# [nan 'bing.wu' 'robert.cui' 'KenGrierson' 'Amritpal.Manak'
#  'amarjit.dhunna' 'mohit' 'behzad.basir' 'megan.croley' 'thecrispy1'
#  'Will' 'lorraine_Nexxus' 'Alexey.tregub']
#
#
#
# 13

# %%
print("Number of reporters: \n")
print(dnn_df['reporter.name'].nunique())
print('\n\n')
print(dnn_df['reporter.name'].unique())
print('\n\n')
print(len(dnn_df['reporter.name'].unique()))

# %%
print("Number of issue status: \n")
print(dnn_df['status.name'].nunique())
print('\n\n')
print(dnn_df['status.name'].unique())
print('\n\n')
print(len(dnn_df['status.name'].unique()))

# %% [markdown]
# ## **Exploring the dataset's columns and their missing values! *Before cleaning stage.**

# %%
print(f'There are {len(dnn_df.columns)} columns in the dataset.')
print("\n******************************\n")
print("Printing Dataset Columns Below: \n")
print(dnn_df.columns)

# %%
print('Printing some data from the dataset for ilustration purpose: \n')
dnn_df.head()

# %%
# Checking for missing values within the data fields before cleaning the data!

print(f"\nThere are: {dnn_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {dnn_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {dnn_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {dnn_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {dnn_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {dnn_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {dnn_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {dnn_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {dnn_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {dnn_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# # **Cleaning the dataset**

# %% [markdown]
# ## **1. Removing unnecessary and useless data fields!**

# %%
# Data cleaning steps

# Remove the unwanted columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount.

dnn_df.drop(columns=['components', 'fixVersions', 'issuetype.subtask', 'versions', 'watches.watchCount', 'resolution.description', 'resolution.name'], inplace = True)

print("\n Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset! \n")

print(f'\n There are now {len(dnn_df.columns)} columns in the dataset.\n')
print(f"\n Printing Data Fields Below: \n {dnn_df.columns} \n")
# Out:
#  Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset!
#
#
#  There are now 17 columns in the dataset.
#
#
#  Printing Data Fields Below:
#  Index(['assignee.name', 'created', 'creator.name', 'description',
#        'issuetype.name', 'priority.name', 'reporter.name', 'resolutiondate',
#        'status.id', 'status.name', 'status.statusCategory.name', 'summary',
#        'updated', 'key', 'storypoints', 'project', 'sprint'],
#       dtype='object')

# %%
print("Printing the new dataset: \n")

dnn_df.head()

# %% [markdown]
# ##**2. Removing the duplicate issues, only keeping one instance of them! Removing isses that have same issue_identifier (KEY)!**

# %%
#Data cleaning steps

# 1.  Remove duplicated issue reports: it doesn't make sense to have ISSUE REPORTS that 
#     have exactly the same content since it was probably a mistake from data input.

# Select all duplicate rows based on column: key
duplicateRowsDF = dnn_df[dnn_df.duplicated(['key'])]
print(f"\nThere are: {len(duplicateRowsDF)} issue duplicates! \n")


print(f"{dnn_df['key'].value_counts()} \n\n")
print(f"Count of column: key, before cleaning is: {dnn_df['key'].count()}\n\n")
print(f"Printing some example issues that have the same identifier: \n")
print(dnn_df.loc[dnn_df['key'] == 'DNN-6746'])
#print(dnn_df.loc[dnn_df['key'] == 'XD-371'])
#print(dnn_df.loc[dnn_df['key'] == 'XD-375'])
# Out:
# There are: 1434 issue duplicates!
#
# DNN-6746     10
# DNN-3239      9
# DNN-4489      9
# DNN-4013      9
# DNN-27332     8
#              ..
# DNN-3433      1
# DNN-4327      1
# DNN-4290      1
# DNN-5091      1
# DNN-3616      1
# Name: key, Length: 1894, dtype: int64
#
#
# Count of column: key, before cleaning is: 3328
#
#
# Printing some example issues that have the same identifier:
#
#      assignee.name                       created  ... project          sprint
# 1276       bing.wu  2014-06-27T11:23:57.000-0700  ...     dnn  2.0.1 Sprint 4
# 1277       bing.wu  2014-06-27T11:23:57.000-0700  ...     dnn  2.0.1 Sprint 4
# 1278       bing.wu  2014-06-27T11:23:57.000-0700  ...     dnn  2.0.1 Sprint 4
# 1279       bing.wu  2014-06-27T11:23:57.000-0700  ...     dnn  2.0.1 Sprint 4
# 1280       bing.wu  2014-06-27T11:23:57.000-0700  ...     dnn  2.0.1 Sprint 4
# 1281       bing.wu  2014-06-27T11:23:57.000-0700  ...     dnn  2.0.1 Sprint 4
# ...

# %%
# Continuation from previous cell

# Select all duplicate rows based on one column
#duplicateRowsDF = dnn_df[dnn_df.duplicated(['key'])]
#print(f"\n There are: {len(duplicateRowsDF)} issue duplicates! \n")

#print('\n*************************************************\n')

# Here I am dropping all duplicates, while only keeping the first instance!
dnn_df = dnn_df.drop_duplicates(subset='key', keep='first')

print(f"Count of column: key, after cleaning is: {dnn_df['key'].count()}\n\n")
print(f"{dnn_df['key'].value_counts()}\n\n")
print(dnn_df.loc[dnn_df['key'] == 'XD-1507'])
print(dnn_df.loc[dnn_df['key'] == 'XD-371'])
print(dnn_df.loc[dnn_df['key'] == 'XD-375'])


# Here I check for duplicate rows based on all columns, 
# i.e. rows where all columns have same values. 
duplicated = dnn_df[dnn_df.duplicated()]
print(f"\nFinally, there are: {len(duplicated)} duplicates")
# Out:
# Count of column: key, after cleaning is: 1894
#
#
# DNN-5745     1
# DNN-3216     1
# DNN-26778    1
# DNN-6234     1
# DNN-5794     1
#             ..
# DNN-2968     1
# DNN-3792     1
# DNN-5711     1
# DNN-7378     1
# DNN-3616     1
# Name: key, Length: 1894, dtype: int64
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **3. Removing issues that do not have a creator.name recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty creator field. by default, 
#     all issues have to have a creator in JIRA

print(f"Count of column: creator.name, before cleaning is: {dnn_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name before cleaning, is: {dnn_df['creator.name'].isnull().sum()}. \n\n\n\n")

dnn_df.dropna(subset = ["creator.name"], inplace=True)

print(f"Count of column: creator.name, after cleaning is: {dnn_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name after cleaning, is: {dnn_df['creator.name'].isnull().sum()}. \n\n")

print(dnn_df['creator.name'].value_counts())

print('\n\n')
print(dnn_df.loc[(dnn_df['creator.name'] == '')])
print('\n\n')
dnn_df.loc[(dnn_df['creator.name'].isnull())]
# Out:
# Count of column: creator.name, before cleaning is: 1894
#
# Count of missing values in the field: creator.name before cleaning, is: 0.
#
#
#
#
# Count of column: creator.name, after cleaning is: 1894
#
# Count of missing values in the field: creator.name after cleaning, is: 0.
#
#
# jbrinkman                 204
# cnurse                    138
# KenGrierson               116
# leupold                    93
# cathal                     67
#                          ...
# tstone@exacttarget.com      1
# saul.williams               1
# kall2sollies                1
# Aricie                      1
# rsiera                      1
# Name: creator.name, Length: 217, dtype: int64
#
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **4. Removing empty issues, i.e. issues that do not have a description and summary.**

# %%
#Data cleaning steps

# 3.  issue reports with empty title or body: 
#     these are probably data input errors or tests, meaningless reports. 

print(f"Count of column: key, before removing issues with no description is: {dnn_df['key'].count()}\n\n")
print(f"\n There are: {dnn_df['description'].isnull().sum()}  missing values in the DESCRIPTION field! \n")
print(f"\n There are: {dnn_df['summary'].isnull().sum()}  missing values in the SUMMARY field! \n")

#dnn_df[(dnn_df['issuetype.name'].isnull())&dnn_df['description'].isnull()&dnn_df['summary'].isnull()]
#dnn_df[(dnn_df['issuetype.name'].isnull())|dnn_df['description'].isnull()|dnn_df['summary'].isnull()].head(150)
# Out:
# Count of column: key, before removing issues with no description is: 1894
#
#
#
#  There are: 20  missing values in the DESCRIPTION field!
#
#
#  There are: 0  missing values in the SUMMARY field!

# %%
dnn_df.dropna(subset=['description'], inplace=True)
print(f"Count of column: key, after removing issues with no description is: {dnn_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description is: 1874

# %%
dnn_df.dropna(subset=['description', 'summary'], inplace=True)
print(f"Count of column: key, after removing issues with no description (summary too) is: {dnn_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description (summary too) is: 1874

# %% [markdown]
# ## **5. Removing issues that do not have a ASSIGNEE.NAME recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty asignee.name field.

print(f"Count of column: assignee.name, before cleaning is: {dnn_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name before cleaning, is: {dnn_df['assignee.name'].isnull().sum()}. \n\n\n\n")

#dnn_df.dropna(subset = ["assignee.name"], inplace=True)

print(f"Count of column: assignee.name, after cleaning is: {dnn_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name after cleaning, is: {dnn_df['assignee.name'].isnull().sum()}. \n\n")

print(dnn_df['assignee.name'].value_counts())
print('\n\n')
print(dnn_df['assignee.name'].unique())
print('\n\n')
print(dnn_df.loc[(dnn_df['assignee.name'] == '')])
print('\n\n')
dnn_df.loc[(dnn_df['assignee.name'].isnull())]

# %% [markdown]
# # **After Cleaning the Data**

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses After Cleaning the Data**

# %%
print("Number of sprints: \n")
print(dnn_df.sprint.nunique())
print(dnn_df.sprint.unique())
print('\n\n')
print(len(dnn_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 103
# ['Sprint 2' 'Sprint 1' nan '7.2.2 Sprint 2' 'Sprint 0' '7.3.0 Sprint 6'
#  '7.2.1 Sprint 4' '7.2.2 Sprint 3' '7.3.0 Sprint 5' '7.3.0 Sprint 2'
#  '7.2.1 Sprint 3' 'Platform 8.0 - Sprint 14' 'Sprint 3' '7.2.1 Sprint 2'
#  'Sprint 4' '7.3.0 Sprint 1' 'Sprint 6' '7.3.1 Sprint 2'
#  '7.2.2 Sprint 1 (Platform)' '7.3.0 Sprint 4' 'Sprint 5'
#  'Content 9.0 - Sprint 3' 'Platform 8.1 - Sprint 2'
#  'Platform 8.1 - Sprint 4' 'Engage 9.0 - Sprint 2'
#  'Platform 8.1 - Sprint 1' 'Content 8.4 - Sprint 4 (CF)'
#  'Content 9.0 - Sprint 1' 'Platform 8.0.1 - Sprint 4 (CF)'
#  'Platform 8.0.1 - Sprint 3' 'Platform 8.0.1 - Sprint 2'
#  'Content 8.4 - Sprint 1' 'Platform 8.0.1 - Sprint 1'
#  'Content 8.3 - Sprint 4' 'Platform 8.0 - Sprint 15 (FF)'
#  'Content 8.3 - Sprint 5 (FF)' 'Engage 8.3.0 - Sprint 5 (FF)'
#  'Platform 8.0 - Sprint 13' 'Platform 8.0 - Sprint 12'
#  'Platform 8.0 - Sprint 11' 'Platform 8.0 - Sprint 11 QA'
# ...

# %%
print("Number of issues: \n")
print(dnn_df.key.nunique())
print(dnn_df.key.unique())
print('\n\n')
print(len(dnn_df.key.unique()))
# Out:
# Number of issues:
#
# 1874
# ['DNN-27698' 'DNN-27696' 'DNN-27688' ... 'DNN-2949' 'DNN-2941' 'DNN-1']
#
#
#
# 1874

# %%
print("Number of developers: \n")
print(dnn_df['assignee.name'].nunique())
print('\n\n')
print(dnn_df['assignee.name'].unique())
print('\n\n')
print(len(dnn_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 12
#
#
#
# [nan 'bing.wu' 'robert.cui' 'KenGrierson' 'Amritpal.Manak'
#  'amarjit.dhunna' 'mohit' 'behzad.basir' 'megan.croley' 'thecrispy1'
#  'Will' 'lorraine_Nexxus' 'Alexey.tregub']
#
#
#
# 13

# %%
print("Number of reporters: \n")
print(dnn_df['reporter.name'].nunique())
print('\n\n')
print(dnn_df['reporter.name'].unique())
print('\n\n')
print(len(dnn_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 216
#
#
#
# ['donker' 'jbrinkman' 'george.alatrash' 'sachatrauwaen' 'KenGrierson'
#  'igrek' 'bogdanl' 'Jasper@dotcontrol' 'BobKruger' 'coolcoyotejosh' 'anon'
#  'dpeterson@goldprospectors.org' 'mryckman' 'weggetor' 'benigemperle'
#  'lorraine_Nexxus' 'dukesb11' 'ept' 'gdemotchkine@gmail.com' 'erikvb'
#  'messmail' 'mvanlaar' 'sherifalalfy@hotmail.com' 'tstone@exacttarget.com'
#  'brucerchapman' 'dougc@sicam.com' 'jsheely' 'nukealexs' 'rogerselwyn'
#  'sbwalker' 'jgirerd' 'rwitvoet@innophase.nl' 'gareth.benjamin'
#  'alex.befus' 'hismightiness' 'Airstream345' 'mohit' 'schotman'
#  'cmsxpress' 'Natasha.zavorotny' 'stephane.peyroutet@pcs.fr'
#  'israel.martinez' 'mathisjay' 'michael.doxsey' 'cathal' 'agx' 'agrueso'
#  'francesco.rivola' 'christoc' 'matthall' 'Maikl' 'ashish.prasad'
#  'zyhfish' 'intelligentnetware' 'trouble2' 'robert.cui' 'Assgier'
#  'cristian.vintila' 'leupold' 'chadwixk' 'rypki' 'jenasysdesign'
# ...

# %% [markdown]
# ## **Exploring the dataset after cleaning (General Descriptives, etc.)**

# %%
print("\n******************************\n")
print("Printing Dataset Shape After Cleaning: \n")
print(dnn_df.shape)
print("\n******************************\n")
print("Printing Dataset Descriptives After Cleaning: \n")
print(dnn_df.describe())
print("\n******************************\n")
print("Printing Dataset Information After Cleaning: \n")
print(dnn_df.info())

# %% [markdown]
# ## **Analyzing the cleaned data below (Missing Values)**

# %%
print("\nCheck the number of total missing values in the Open-Source Project \n")
print(dnn_df.isnull())
print("\n\n******************************\n")
print("\nCheck the data fields that contain missing values in the Open-Source Project \n")
print(dnn_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(dnn_df.isnull().sum().sum())

# %%
# Checking for missing values after cleaning the data!

print(f"\nThere are: {dnn_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {dnn_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {dnn_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {dnn_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {dnn_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {dnn_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {dnn_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {dnn_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {dnn_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {dnn_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# ## **Checking for Scrum Rules. After cleaning stage**

# %%
print("\n Check the unique developers (usernames) in the Open-Source Project \n")
#Count and report the unique values

print(len(dnn_df['assignee.name'].unique()))
print('\n****************************************************\n')
dnn_df['assignee.name'].unique()

# %%
print("\n Check the unique reporters (Product Owners) in the Open-Source Project \n")
#Count and report the unique values

print(len(dnn_df['reporter.name'].unique()))
print('\n****************************************************\n')
dnn_df['reporter.name'].unique()

# %%
print("\n Check the unique creators in the Open-Source Project \n")
#Count and report the unique values

print(len(dnn_df['creator.name'].unique()))
print('\n****************************************************\n')
dnn_df['creator.name'].unique()

# %%
print("\n Check the total number of issues in the Open-Source Project \n")

print(dnn_df['key'].count())
#dnn_df[dnn_df.key[0]].count()
#dnn_df.count(0)

# %%
print("\n Check the total number of sprints in the Open-Source Project \n")

print(dnn_df['sprint'].count())
#dnn_df[dnn_df.key[0]].count()
#dnn_df.count(0)

# %%
print("\n******************************\n")
print("Printing Project Unique Story Points and their Count: \n")
print(dnn_df['storypoints'].value_counts())

#print("\n******************************\n")
#print("Printing the row (issue) where the number of story points is 15 \n")
#print(dnn_df.loc[dnn_df['storypoints'] == 15])

# %%
print("\n Exploring the data field: Created, i.e. date when the issues in this project were created. \n")
print(dnn_df['created'].head(1))
print(dnn_df['created'].value_counts())

# %%
print("\n Exploring the data field: Resolutiondate, i.e. date when the issues in this project were resolved. \n")
print(len(dnn_df['resolutiondate']))
print(dnn_df['resolutiondate'].tail(5))
print(dnn_df['resolutiondate'].value_counts())

print('\n\n')
dnn_df['resolutiondate'].tail(20)

# %%
print("\n Exploring the data field: Updated, i.e. date when the issues in this project were updated. \n")
print(dnn_df['updated'])
print(dnn_df['updated'].value_counts())

# %% [markdown]
# ## **Working with DATES!**

# %%
dnn_df.info()

# %%
#Converting the dates to pandas datetime format, which will be easier to process.

dnn_df['created'] = pd.to_datetime(dnn_df.created)

# %%
dnn_df.head()

# %%
dnn_df.dtypes

# %%
dnn_df.created.dt.dayofyear

# %%
dnn_df['resolutiondate'] = pd.to_datetime(dnn_df.resolutiondate)

# %%
dnn_df.resolutiondate.dt.dayofyear
