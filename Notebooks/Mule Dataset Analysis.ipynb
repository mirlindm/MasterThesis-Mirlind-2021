# %% [markdown]
# ## **Upload the dataset**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87f79b8e-075e-4ab4-a0bf-4c64685b61eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87f79b8e-075e-4ab4-a0bf-4c64685b61eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mule_dataframe.csv to mule_dataframe.csv

# %% [markdown]
# ## **Reading the dataset. Providing initial descriptives for the project's data. Before cleaning stage.**

# %%
import pandas as pd

mule_df = pd.read_csv("mule_dataframe.csv")

print("\n******************************\n")
print("Printing Dataset Initial Shape: \n")
print(mule_df.shape)
print("\n******************************\n")
print("Printing Dataset Initial Descriptives: \n")
print(mule_df.describe())
print("\n******************************\n")
print("Printing Dataset Information: \n")
print(mule_df.info())
# Out:
# ******************************
#
# Printing Dataset Initial Shape:
#
# (1497, 24)
#
# ******************************
#
# Printing Dataset Initial Descriptives:
#
#          status.id  watches.watchCount  storypoints
# count  1497.000000         1497.000000  1497.000000
# mean      5.666667            1.511690     4.494990
# std       1.228741            1.099965     3.879899
# min       1.000000            0.000000     0.000000
# 25%       6.000000            1.000000     1.000000
# 50%       6.000000            1.000000     5.000000
# 75%       6.000000            2.000000     8.000000
# max       6.000000           12.000000    21.000000
#
# ******************************
#
# Printing Dataset Information:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
# ...

# %%
print("\n Check the number of total missing values in the Open-Source Project \n")
#To-DO
print(mule_df.isnull())
print("\n Check the data fields that contain missing values in the Open-Source Project \n")
#To-DO
print(mule_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(mule_df.isnull().sum().sum())
# Out:
#  Check the number of total missing values in the Open-Source Project
#
#       assignee.name  components  created  ...  storypoints  project  sprint
# 0             False       False    False  ...        False    False   False
# 1             False       False    False  ...        False    False   False
# 2             False       False    False  ...        False    False   False
# 3             False       False    False  ...        False    False   False
# 4             False       False    False  ...        False    False   False
# ...             ...         ...      ...  ...          ...      ...     ...
# 1492          False       False    False  ...        False    False    True
# 1493          False       False    False  ...        False    False    True
# 1494          False       False    False  ...        False    False    True
# 1495          False       False    False  ...        False    False   False
# ...

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses Before Cleaning the Data**

# %%
print("Number of sprints: \n")
print(mule_df.sprint.nunique())
print(mule_df.sprint.unique())
print('\n\n')
print(len(mule_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 104
# ['startDate=2016-04-27T11:27:32.496-05:00'
#  'startDate=2016-03-03T11:00:57.861-06:00' 'startDate=<null>'
#  'startDate=2016-04-28T11:51:14.884-05:00'
#  'startDate=2016-04-14T11:50:43.106-05:00'
#  'startDate=2015-04-09T10:59:36.335-05:00' nan
#  'startDate=2016-04-11T10:36:05.985-05:00'
#  'startDate=2016-03-31T11:18:01.526-05:00'
#  'startDate=2016-03-28T10:46:39.508-05:00'
#  'startDate=2016-03-17T11:38:15.766-05:00'
#  'startDate=2016-03-14T10:53:19.767-05:00'
#  'startDate=2016-02-29T09:42:26.488-06:00'
#  'startDate=2016-03-03T11:41:29.201-06:00'
#  'startDate=2016-02-18T11:25:39.042-06:00'
#  'startDate=2016-02-18T08:50:54.137-06:00'
#  'startDate=2016-02-04T20:59:53.373-06:00'
#  'startDate=2016-02-15T08:53:09.519-06:00'
#  'startDate=2016-02-10T12:51:29.183-06:00'
#  'startDate=2016-01-18T09:45:59.558-06:00'
#  'startDate=2016-01-21T13:05:00.738-06:00'
#  'startDate=2016-01-21T10:50:33.545-06:00'
#  'startDate=2016-01-07T11:20:23.605-06:00'
# ...

# %%
print("Number of issues: \n")
print(mule_df.key.nunique())
print(mule_df.key.unique())
print('\n\n')
print(len(mule_df.key.unique()))
# Out:
# Number of issues:
#
# 1281
# ['MULE-9674' 'MULE-9673' 'MULE-9667' ... 'MULE-6087' 'MULE-5990'
#  'MULE-5382']
#
#
#
# 1281

# %%
print("Number of developers: \n")
print(mule_df['assignee.name'].nunique())
print('\n\n')
print(mule_df['assignee.name'].unique())
print('\n\n')
print(len(mule_df['assignee.name'].unique()))

# %%
print("Number of reporters: \n")
print(mule_df['reporter.name'].nunique())
print('\n\n')
print(mule_df['reporter.name'].unique())
print('\n\n')
print(len(mule_df['reporter.name'].unique()))

# %%
print("Number of issue status: \n")
print(mule_df['status.name'].nunique())
print('\n\n')
print(mule_df['status.name'].unique())
print('\n\n')
print(len(mule_df['status.name'].unique()))

# %% [markdown]
# ## **Exploring the dataset's columns and their missing values! *Before cleaning stage.**

# %%
print(f'There are {len(mule_df.columns)} columns in the dataset.')
print("\n******************************\n")
print("Printing Dataset Columns Below: \n")
print(mule_df.columns)

# %%
print('Printing some data from the dataset for ilustration purpose: \n')
mule_df.head()

# %%
# Checking for missing values within the data fields before cleaning the data!

print(f"\nThere are: {mule_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {mule_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {mule_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {mule_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {mule_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {mule_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {mule_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {mule_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {mule_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {mule_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# # **Cleaning the dataset**

# %% [markdown]
# ## **1. Removing unnecessary and useless data fields!**

# %%
# Data cleaning steps

# Remove the unwanted columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount.

mule_df.drop(columns=['components', 'fixVersions', 'issuetype.subtask', 'versions', 'watches.watchCount', 'resolution.description', 'resolution.name'], inplace = True)

print("\n Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset! \n")

print(f'\n There are now {len(mule_df.columns)} columns in the dataset.\n')
print(f"\n Printing Data Fields Below: \n {mule_df.columns} \n")
# Out:
#  Columns: components, fixVersions, issuetype.subtask, versions, watches.watchCount, resolution.description, resolution.name have been removed from the dataset!
#
#
#  There are now 17 columns in the dataset.
#
#
#  Printing Data Fields Below:
#  Index(['assignee.name', 'created', 'creator.name', 'description',
#        'issuetype.name', 'priority.name', 'reporter.name', 'resolutiondate',
#        'status.id', 'status.name', 'status.statusCategory.name', 'summary',
#        'updated', 'key', 'storypoints', 'project', 'sprint'],
#       dtype='object')

# %%
print("Printing the new dataset: \n")

mule_df.head()

# %% [markdown]
# ##**2. Removing the duplicate issues, only keeping one instance of them! Removing isses that have same issue_identifier (KEY)!**

# %%
#Data cleaning steps

# 1.  Remove duplicated issue reports: it doesn't make sense to have ISSUE REPORTS that 
#     have exactly the same content since it was probably a mistake from data input.

# Select all duplicate rows based on column: key
duplicateRowsDF = mule_df[mule_df.duplicated(['key'])]
print(f"\nThere are: {len(duplicateRowsDF)} issue duplicates! \n")


print(f"{mule_df['key'].value_counts()} \n\n")
print(f"Count of column: key, before cleaning is: {mule_df['key'].count()}\n\n")
print(f"Printing some example issues that have the same identifier: \n")
print(mule_df.loc[mule_df['key'] == 'MULE-9046'])
# print(mule_df.loc[mule_df['key'] == 'XD-371'])
# print(mule_df.loc[mule_df['key'] == 'XD-375'])
# Out:
# There are: 216 issue duplicates!
#
# MULE-9046    11
# MULE-6566     8
# MULE-7001     6
# MULE-6844     6
# MULE-9072     6
#              ..
# MULE-9148     1
# MULE-8239     1
# MULE-7920     1
# MULE-8215     1
# MULE-9357     1
# Name: key, Length: 1281, dtype: int64
#
#
# Count of column: key, before cleaning is: 1497
#
#
# Printing some example issues that have the same identifier:
#
#       assignee.name  ...                                   sprint
# 332  rodrigo.merino  ...  startDate=2015-11-05T10:48:06.531-06:00
# 333  rodrigo.merino  ...  startDate=2015-11-05T10:48:06.531-06:00
# 334  rodrigo.merino  ...  startDate=2015-11-05T10:48:06.531-06:00
# 335  rodrigo.merino  ...  startDate=2015-11-05T10:48:06.531-06:00
# 336  rodrigo.merino  ...  startDate=2015-11-05T10:48:06.531-06:00
# 337  rodrigo.merino  ...  startDate=2015-11-05T10:48:06.531-06:00
# 338  rodrigo.merino  ...  startDate=2015-11-05T10:48:06.531-06:00
# ...

# %%
# Continuation from previous cell

# Select all duplicate rows based on one column
#duplicateRowsDF = mule_df[mule_df.duplicated(['key'])]
#print(f"\n There are: {len(duplicateRowsDF)} issue duplicates! \n")

#print('\n*************************************************\n')

# Here I am dropping all duplicates, while only keeping the first instance!
mule_df = mule_df.drop_duplicates(subset='key', keep='first')

print(f"Count of column: key, after cleaning is: {mule_df['key'].count()}\n\n")
print(f"{mule_df['key'].value_counts()}\n\n")
# print(mule_df.loc[mule_df['key'] == 'XD-1507'])
# print(mule_df.loc[mule_df['key'] == 'XD-371'])
# print(mule_df.loc[mule_df['key'] == 'XD-375'])


# Here I check for duplicate rows based on all columns, 
# i.e. rows where all columns have same values. 
duplicated = mule_df[mule_df.duplicated()]
print(f"\nFinally, there are: {len(duplicated)} duplicates")
# Out:
# Count of column: key, after cleaning is: 1281
#
#
# MULE-9485    1
# MULE-7221    1
# MULE-8555    1
# MULE-8205    1
# MULE-7326    1
#             ..
# MULE-9351    1
# MULE-7846    1
# MULE-8052    1
# MULE-8421    1
# MULE-9357    1
# Name: key, Length: 1281, dtype: int64
#
#
#
# Finally, there are: 0 duplicates

# %% [markdown]
# ## **3. Removing issues that do not have a creator.name recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty creator field. by default, 
#     all issues have to have a creator in JIRA

print(f"Count of column: creator.name, before cleaning is: {mule_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name before cleaning, is: {mule_df['creator.name'].isnull().sum()}. \n\n\n\n")

mule_df.dropna(subset = ["creator.name"], inplace=True)

print(f"Count of column: creator.name, after cleaning is: {mule_df['creator.name'].count()}\n")
print(f"Count of missing values in the field: creator.name after cleaning, is: {mule_df['creator.name'].isnull().sum()}. \n\n")

print(mule_df['creator.name'].value_counts())

print('\n\n')
print(mule_df.loc[(mule_df['creator.name'] == '')])
print('\n\n')
mule_df.loc[(mule_df['creator.name'].isnull())]
# Out:
# Count of column: creator.name, before cleaning is: 1278
#
# Count of missing values in the field: creator.name before cleaning, is: 3.
#
#
#
#
# Count of column: creator.name, after cleaning is: 1278
#
# Count of missing values in the field: creator.name after cleaning, is: 0.
#
#
# mariano.gonzalez      245
# pablo.kraan           102
# alejandro.sequeira    101
# pablo.lagreca.ce       85
# afelisatti             85
#                      ...
# pablo.luna              1
# robin.pille             1
# valentin.despa          1
# sebastian.gramano       1
# rhoegg                  1
# Name: creator.name, Length: 99, dtype: int64
#
#
#
# Empty DataFrame
# Columns: [assignee.name, created, creator.name, description, issuetype.name, priority.name, reporter.name, resolutiondate, status.id, status.name, status.statusCategory.name, summary, updated, key, storypoints, project, sprint]
# Index: []
# Empty DataFrame
# ...

# %% [markdown]
# ## **4. Removing empty issues, i.e. issues that do not have a description and summary.**

# %%
#Data cleaning steps

# 3.  issue reports with empty title or body: 
#     these are probably data input errors or tests, meaningless reports. 

print(f"Count of column: key, before removing issues with no description is: {mule_df['key'].count()}\n\n")
print(f"\n There are: {mule_df['description'].isnull().sum()}  missing values in the DESCRIPTION field! \n")
print(f"\n There are: {mule_df['summary'].isnull().sum()}  missing values in the SUMMARY field! \n")

#mule_df[(mule_df['issuetype.name'].isnull())&mule_df['description'].isnull()&mule_df['summary'].isnull()]
#mule_df[(mule_df['issuetype.name'].isnull())|mule_df['description'].isnull()|mule_df['summary'].isnull()].head(150)
# Out:
# Count of column: key, before removing issues with no description is: 1278
#
#
#
#  There are: 0  missing values in the DESCRIPTION field!
#
#
#  There are: 0  missing values in the SUMMARY field!

# %%
mule_df.dropna(subset=['description'], inplace=True)
print(f"Count of column: key, after removing issues with no description is: {mule_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description is: 1278

# %%
mule_df.dropna(subset=['description', 'summary'], inplace=True)
print(f"Count of column: key, after removing issues with no description (summary too) is: {mule_df['key'].count()}\n\n")
# Out:
# Count of column: key, after removing issues with no description (summary too) is: 1278

# %% [markdown]
# ## **5. Removing issues that do not have a ASSIGNEE.NAME recorded!**

# %%
#Data cleaning steps

# 2.  Remove issue reports with the empty asignee.name field.

print(f"Count of column: assignee.name, before cleaning is: {mule_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name before cleaning, is: {mule_df['assignee.name'].isnull().sum()}. \n\n\n\n")

#mule_df.dropna(subset = ["assignee.name"], inplace=True)

print(f"Count of column: assignee.name, after cleaning is: {mule_df['assignee.name'].count()}\n")
print(f"Count of missing values in the field: assignee.name after cleaning, is: {mule_df['assignee.name'].isnull().sum()}. \n\n")

print(mule_df['assignee.name'].value_counts())
print('\n\n')
print(mule_df['assignee.name'].unique())
print('\n\n')
print(mule_df.loc[(mule_df['assignee.name'] == '')])
print('\n\n')
mule_df.loc[(mule_df['assignee.name'].isnull())]

# %% [markdown]
# # **After Cleaning the Data**

# %% [markdown]
# ## **Calculating the number of Sprints, Issues, Developers, Reporters and Issue Statuses After Cleaning the Data**

# %%
print("Number of sprints: \n")
print(mule_df.sprint.nunique())
print(mule_df.sprint.unique())
print('\n\n')
print(len(mule_df.sprint.unique()))
# Out:
# Number of sprints:
#
# 104
# ['startDate=2016-04-27T11:27:32.496-05:00'
#  'startDate=2016-03-03T11:00:57.861-06:00' 'startDate=<null>'
#  'startDate=2016-04-28T11:51:14.884-05:00'
#  'startDate=2016-04-14T11:50:43.106-05:00'
#  'startDate=2015-04-09T10:59:36.335-05:00' nan
#  'startDate=2016-04-11T10:36:05.985-05:00'
#  'startDate=2016-03-31T11:18:01.526-05:00'
#  'startDate=2016-03-28T10:46:39.508-05:00'
#  'startDate=2016-03-17T11:38:15.766-05:00'
#  'startDate=2016-03-14T10:53:19.767-05:00'
#  'startDate=2016-02-29T09:42:26.488-06:00'
#  'startDate=2016-03-03T11:41:29.201-06:00'
#  'startDate=2016-02-18T11:25:39.042-06:00'
#  'startDate=2016-02-18T08:50:54.137-06:00'
#  'startDate=2016-02-04T20:59:53.373-06:00'
#  'startDate=2016-02-15T08:53:09.519-06:00'
#  'startDate=2016-02-10T12:51:29.183-06:00'
#  'startDate=2016-01-18T09:45:59.558-06:00'
#  'startDate=2016-01-21T13:05:00.738-06:00'
#  'startDate=2016-01-21T10:50:33.545-06:00'
#  'startDate=2016-01-07T11:20:23.605-06:00'
# ...

# %%
print("Number of issues: \n")
print(mule_df.key.nunique())
print(mule_df.key.unique())
print('\n\n')
print(len(mule_df.key.unique()))
# Out:
# Number of issues:
#
# 1278
# ['MULE-9674' 'MULE-9673' 'MULE-9667' ... 'MULE-6087' 'MULE-5990'
#  'MULE-5382']
#
#
#
# 1278

# %%
print("Number of developers: \n")
print(mule_df['assignee.name'].nunique())
print('\n\n')
print(mule_df['assignee.name'].unique())
print('\n\n')
print(len(mule_df['assignee.name'].unique()))
# Out:
# Number of developers:
#
# 38
#
#
#
# ['mariano.gonzalez' 'gsfernandes' 'alejandro.garcia' 'Pablo.Musumeci'
#  'rodrigo.merino' 'esteban.wasinger' 'alejandro.sequeira' 'afelisatti'
#  'pablo.lagreca.ce' 'dfeist' 'matias.baldini' 'juan.desimoni' nan
#  'pablo.kraan' 'pablo.cabrera' 'alejandro.nosenzo' 'alejandro.iannucci'
#  'andres.gregoire' 'marcosnc' 'vromero' 'aiannucci' 'rrinaudo' 'dandiep'
#  'reza.shafii' 'marcos.nunezcortes' 'luciano.gandini' 'pabad' 'wai.ip'
#  'ignacio.gleria' 'mariano.achaval' 'dirk' 'athieme' 'fernando.federico'
#  'evangelinamrm' 'christopher.mordue' 'svacas' 'janet.revell'
#  'natalia.garcia' 'scamina']
#
#
#
# 39

# %%
print("Number of reporters: \n")
print(mule_df['reporter.name'].nunique())
print('\n\n')
print(mule_df['reporter.name'].unique())
print('\n\n')
print(len(mule_df['reporter.name'].unique()))
# Out:
# Number of reporters:
#
# 105
#
#
#
# ['juan.desimoni' 'gsfernandes' 'mariano.gonzalez' 'afelisatti'
#  'rodrigo.merino' 'alejandro.garcia' 'luciano.gandini' 'facundo.lopez'
#  'alejandro.iannucci' 'alejandro.sequeira' 'Pablo.Musumeci' 'dfeist'
#  'esteban.wasinger' 'matias.baldini' 'diego.strubolini' 'pablo.lagreca.ce'
#  'pablo.kraan' 'pablo.cabrera' 'alejandro.nosenzo' 'melissa.vanderhecht'
#  'damian.sima' 'federico.amdan' 'nooruldgl' 'roger.butenuth' 'fededonna'
#  'jesica.fera' 'farolfo' 'javaduke' 'andres.gregoire' 'sdhanemkula'
#  'dpelaez' 'jorge.garcia' 'german.solis' 'marcosnc' 'lautaro.fernandez'
#  'matias.pentreath' 'svacas' 'nahuel' 'pmantellini' 'dandiep'
#  'mariano.capurro' 'alejandro.dobniewski' 'maru' 'chiragnarangmulesoft'
#  'bgillis' 'vromero' 'pc.at.bb' 'gabriel.dimech' 'mmonsalvo'
#  'roman.deoliveira' 'davidd' 'arubalac' 'wai.ip' 'aiannucci'
#  'reynold_lariza' 'eleonora.ortega' 'pabad' 'rrinaudo' 'pablo.luna'
# ...

# %% [markdown]
# ## **Exploring the dataset after cleaning (General Descriptives, etc.)**

# %%
print("\n******************************\n")
print("Printing Dataset Shape After Cleaning: \n")
print(mule_df.shape)
print("\n******************************\n")
print("Printing Dataset Descriptives After Cleaning: \n")
print(mule_df.describe())
print("\n******************************\n")
print("Printing Dataset Information After Cleaning: \n")
print(mule_df.info())

# %% [markdown]
# ## **Analyzing the cleaned data below (Missing Values)**

# %%
print("\nCheck the number of total missing values in the Open-Source Project \n")
print(mule_df.isnull())
print("\n\n******************************\n")
print("\nCheck the data fields that contain missing values in the Open-Source Project \n")
print(mule_df.isnull().sum())
print("\n******************************\n")
print("Printing Dataset Total Number of Missing Values: \n")
print(mule_df.isnull().sum().sum())

# %%
# Checking for missing values after cleaning the data!

print(f"\nThere are: {mule_df['description'].isnull().sum()} missing values in the DESCRIPTION field!\n")
print(f"\nThere are: {mule_df['summary'].isnull().sum()} missing values in the SUMMARY field!\n")
print(f"\nThere are: {mule_df['issuetype.name'].isnull().sum()} missing values in the ISSUETYPE.NAME field!\n")
print(f"\nThere are: {mule_df['key'].isnull().sum()} missing values in the KEY field!\n")
print(f"\nThere are: {mule_df['sprint'].isnull().sum()} missing values in the SPRINT field!\n")
print(f"\nThere are: {mule_df['creator.name'].isnull().sum()} missing values in the CREATOR.NAME field!\n")
print(f"\nThere are: {mule_df['assignee.name'].isnull().sum()} missing values in the ASIGNEE.NAME field!\n")
print(f"\nThere are: {mule_df['reporter.name'].isnull().sum()} missing values in the REPORTER.NAME field!\n")
print(f"\nThere are: {mule_df['created'].isnull().sum()} missing values in the CREATED field!\n")
print(f"\nThere are: {mule_df['resolutiondate'].isnull().sum()} missing values in the RESOLUTIONDATE field!\n")

# %% [markdown]
# ## **Checking for Scrum Rules. After cleaning stage**

# %%
print("\n Check the unique developers (usernames) in the Open-Source Project \n")
#Count and report the unique values

print(len(mule_df['assignee.name'].unique()))
print('\n****************************************************\n')
mule_df['assignee.name'].unique()

# %%
print("\n Check the unique reporters (Product Owners) in the Open-Source Project \n")
#Count and report the unique values

print(len(mule_df['reporter.name'].unique()))
print('\n****************************************************\n')
mule_df['reporter.name'].unique()

# %%
print("\n Check the unique creators in the Open-Source Project \n")
#Count and report the unique values

print(len(mule_df['creator.name'].unique()))
print('\n****************************************************\n')
mule_df['creator.name'].unique()

# %%
print("\n Check the total number of issues in the Open-Source Project \n")

print(mule_df['key'].count())
#mule_df[mule_df.key[0]].count()
#mule_df.count(0)

# %%
print("\n Check the total number of sprints in the Open-Source Project \n")

print(mule_df['sprint'].count())
#mule_df[mule_df.key[0]].count()
#mule_df.count(0)

print(mule_df['sprint'].value_counts())

mule_df.head()

# %%
print("\n******************************\n")
print("Printing Project Unique Story Points and their Count: \n")
print(mule_df['storypoints'].value_counts())

#print("\n******************************\n")
#print("Printing the row (issue) where the number of story points is 15 \n")
#print(mule_df.loc[mule_df['storypoints'] == 15])

# %%
print("\n Exploring the data field: Created, i.e. date when the issues in this project were created. \n")
print(mule_df['created'].head(1))
print(mule_df['created'].value_counts())

# %%
print("\n Exploring the data field: Resolutiondate, i.e. date when the issues in this project were resolved. \n")
print(len(mule_df['resolutiondate']))
print(mule_df['resolutiondate'].tail(5))
print(mule_df['resolutiondate'].value_counts())

print('\n\n')
mule_df['resolutiondate'].tail(20)

# %%
print("\n Exploring the data field: Updated, i.e. date when the issues in this project were updated. \n")
print(mule_df['updated'])
print(mule_df['updated'].value_counts())

# %% [markdown]
# ## **Working with DATES!**

# %%
mule_df.info()

# %%
#Converting the dates to pandas datetime format, which will be easier to process.

mule_df['created'] = pd.to_datetime(mule_df.created)

# %%
mule_df.head()

# %%
mule_df.dtypes

# %%
mule_df.created.dt.dayofyear

# %%
mule_df['resolutiondate'] = pd.to_datetime(mule_df.resolutiondate)

# %%
mule_df.resolutiondate.dt.dayofyear
